# %% [markdown]
# ## Extracting Climate Finance Tools

# %% [markdown]
# The goal of this project is to identify climate finance laws and tools from around the world. We now have a grouping of laws themselves, news articles, press releases, and company plans that may mention these types of initatives. The next step is to comb through them to find what we need.

# %% [markdown]
# ### Loading the data

# %%
import os
import pandas as pd
import PyPDF2
import fitz  # PyMuPDF - better for detecting formatting like strikethrough
from tqdm.notebook import tqdm
from googletrans import Translator
from nltk import sent_tokenize
import re

# %%
brasil_folder = 'brasil'
china_folder = 'china' 
eu_folder = 'eu'

# %%
def load_files(folder, exclude_strikethrough=True): 
    """
    Load files from a folder, with option to exclude strikethrough text from PDFs.
    
    Args:
        folder: Path to folder containing files
        exclude_strikethrough: If True, excludes crossed-out text from PDFs (default: True)
    """
    df = []
    files = os.listdir(folder)
    for file in tqdm(files, desc=f"Loading files from {folder}"): 
        file_path = os.path.join(folder, file)
        ext = os.path.splitext(file)[-1].lower()
        try:
            if ext == '.pdf':
                text = ""
                if exclude_strikethrough:
                    # Use PyMuPDF to extract text while excluding strikethrough
                    doc = fitz.open(file_path)
                    for page in doc:
                        blocks = page.get_text("dict")["blocks"]
                        for block in blocks:
                            if "lines" in block:
                                for line in block["lines"]:
                                    for span in line["spans"]:
                                        # Check if text has strikethrough flag
                                        # Font flags: bit 4 (value 16) indicates strikethrough
                                        flags = span.get("flags", 0)
                                        is_strikethrough = bool(flags & (1 << 4))
                                        
                                        if not is_strikethrough:
                                            text += span["text"]
                                    text += "\n"
                    doc.close()
                else:
                    # Fallback to PyPDF2
                    with open(file_path, 'rb') as f:
                        reader = PyPDF2.PdfReader(f)
                        for page in reader.pages:
                            try:
                                text += page.extract_text() or ""
                            except Exception:
                                continue
            else:
                with open(file_path, 'r', encoding='utf-8', errors='ignore') as f: 
                    text = f.read()
            df.append({'file': file, 'text': text})
        except Exception as e:
            df.append({'file': file, 'text': '', 'error': str(e)})
    return pd.DataFrame(df)

# %%
b_df = load_files(brasil_folder)
# Out:
# Loading files from brasil:   0%|          | 0/73 [00:00<?, ?it/s]

# %%
#check the 44th item in brasil 
# Look at the text associated with file '44.pdf'
item_44 = b_df[b_df['file'] == '44.pdf']
if not item_44.empty:
    print(item_44.iloc[0]['text'])
else:
    print("44.pdf not found in loaded DataFrame.")
# Out:
# Revogado pelo Decreto nº 11.772, de 2023
# Texto para impressão
# Estabelece as Diretrizes Nacionais sobre Empresas e
# Direitos Humanos.
# , no exercício do cargo de Presidente da República, no uso das
# atribuições que lhe confere o art. 84, , incisos IV e VI, alínea “a”, da Constituição,
# :
# CAPÍTULO I
# DISPOSIÇÕES PRELIMINARES
# Art. 1º Este Decreto estabelece as Diretrizes Nacionais sobre Empresas e Direitos Humanos, para médias e
# grandes empresas, incluídas as empresas multinacionais com atividades no País.
# § 1º Nos termos do disposto na Lei Complementar nº 123, de 14 de dezembro de 2006, as microempresas e as
# empresas de pequeno porte poderão, na medida de suas capacidades, cumprir as Diretrizes de que trata este Decreto,
# observado o disposto no art. 179 da Constituição.
# § 2º As Diretrizes serão implementadas voluntariamente pelas empresas.
# § 3º Ato do Ministro de Estado dos Direitos Humanos instituirá o Selo “Empresa e Direitos Humanos”, destinado às
# empresas que voluntariamente implementarem as Diretrizes de que trata este Decreto.
# Art. 2º São eixos orientadores das Diretrizes Nacionais sobre Empresas e Direitos Humanos:
# I - a obrigação do Estado com a proteção dos direitos humanos em atividades empresariais;
# II - a responsabilidade das empresas com o respeito aos direitos humanos;
# III - o acesso aos mecanismos de reparação e remediação para aqueles que, nesse âmbito, tenham seus direitos
# afetados; e
# IV - a implementação, o monitoramento e a avaliação das Diretrizes.
# CAPÍTULO II
# DA OBRIGAÇÃO DO ESTADO COM A PROTEÇÃO DOS DIREITOS HUMANOS EM ATIVIDADES EMPRESARIAIS
# Art. 3º A responsabilidade do Estado com a proteção dos direitos humanos em atividades empresariais será
# pautada pelas seguintes diretrizes:
# I - capacitação de servidores públicos sobre a temática de direitos humanos e empresas, com foco nas
# responsabilidades da administração pública e das empresas, de acordo com os Princípios Orientadores sobre Empresas
# e Direitos Humanos da Organização das Nações Unidas, principalmente ações de:
# a) sensibilização e promoção da educação contínua dos recursos humanos da administração pública para o
# fortalecimento da cultura em direitos humanos; e
# b) capacitação dos recursos humanos da administração pública para o tratamento das violações aos direitos
# humanos em contexto empresarial, de seus riscos e de seus impactos;
# II - fortalecimento da consonância entre políticas públicas e proteção dos direitos humanos;
# III - aperfeiçoamento dos mecanismos de transparência e de participação social;
# IV - implementação de políticas, normas e incentivos à conduta das empresas quanto aos direitos humanos, por
# meio de:
# 14/10/2025, 13:45
# D9571
# www.planalto.gov.br/ccivil_03/_ato2015-2018/2018/decreto/D9571.htm
# 1/10
# a) exigência de compromisso público de respeito aos direitos humanos e publicação de relatório anual das
# empresas;
# b) estímulo à prestação de contas sobre os riscos de sua operação aos direitos humanos e exigência de adoção
# de medidas de prevenção, controle e reparação; e
# c) estímulo ao estabelecimento de canais de denúncia para os colaboradores, os fornecedores e a comunidade;
# V - prioridade de setores com alto potencial de impacto em direitos humanos, tais como os setores extrativo, de
# varejo e bens de consumo, de infraestrutura, químico e farmacêutico, entre outros;
# VI - desenvolvimento de políticas públicas e realização de alterações no ordenamento jurídico, a fim de:
# a) considerar, além dos impactos diretamente gerados pela empresa, os impactos indiretamente gerados pela
# cadeia de fornecimento;
# b) estimular a criação de medidas adicionais de proteção e a elaboração de matriz de priorização de reparações e
# indenizações para grupos em situação de vulnerabilidade;
# VII - estímulo à adoção, por grandes empresas, de procedimentos adequados de dever de vigilância (
# ) em direitos humanos;
# VIII - orientação da incorporação dos direitos humanos à gestão de riscos de negócios e de parcerias que venha a
# estabelecer, de modo a subsidiar processos decisórios;
# IX - criação de plataformas e fortalecimento de mecanismos de diálogo entre a administração pública, as empresas
# e a sociedade civil;
# X - integração dos direitos humanos ao investimento social, aos projetos de desenvolvimento sustentável para as
# comunidades impactadas e às políticas de patrocínio;
# XI - garantia de condições de trabalho dignas para seus recursos humanos, por meio de ambiente produtivo, com
# remuneração adequada e em condições de liberdade, equidade e segurança, com estímulo à observância desse objetivo
# pelas empresas;
# XII - combate à discriminação nas relações de trabalho e promoção da valorização da diversidade;
# subsidiárias, de entidades sob seu controle direito ou indireto, a fim de não infringir os direitos humanos de seus
# funcionários, colaboradores, terceiros, clientes, comunidade onde atuam e população em geral;
# II - evitar que suas atividades causem, contribuam ou estejam diretamente relacionadas aos impactos negativos
# sobre direitos humanos e aos danos ambientais e sociais,
# III - evitar impactos e danos decorrentes das atividades de suas subsidiárias e de entidades sob seu controle ou
# vinculação direta ou indireta;
# IV - adotar compromisso de respeito aos direitos humanos, aprovado pela alta administração da empresa, no qual
# trará as ações que realizará, para evitar qualquer grau de envolvimento com danos, para controlar e monitorar riscos a
# direitos humanos, assim como as expectativas da empresa em relação aos seus parceiros comerciais e funcionários;
# V - garantir que suas políticas, seus códigos de ética e conduta e seus procedimentos operacionais reflitam o
# compromisso com o respeito aos direitos humanos;
# VI - implementar o compromisso político assumido nas áreas da empresa, publicá-lo e mantê-lo atualizado, com
# destaque, nos sítios eletrônicos e nos canais públicos da empresa e constituir área ou pessoa responsável para
# acompanhar o seu cumprimento;
# VII - promover a consulta livre, prévia e informada das comunidades impactadas pela atividade empresarial;
# VIII - criar políticas e incentivos para que seus parceiros comerciais respeitem os direitos humanos, tais como a
# adoção de critérios e de padrões sociais e ambientais internacionalmente reconhecidos para a seleção e a execução de
# contratos com terceiros, correspondentes ao tamanho da empresa, à complexidade das operações e aos riscos aos
# direitos humanos;
# IX - comunicar internamente que seus colaboradores estão proibidos de adotarem práticas que violem os direitos
# humanos, sob pena de sanções internas;
# X - orientar os colaboradores, os empregados e as pessoas vinculadas à sociedade empresária a adotarem
# postura respeitosa, amistosa e em observância aos direitos humanos;
# XI - estimular entre fornecedores e terceiros um convívio inclusivo e favorável à diversidade;
# 14/10/2025, 13:45
# D9571
# www.planalto.gov.br/ccivil_03/_ato2015-2018/2018/decreto/D9571.htm
# 3/10
# XII - dispor de estrutura de governança para assegurar a implementação efetiva dos compromissos e das políticas
# relativas aos direitos humanos;
# XIII - incorporar os direitos humanos na gestão corporativa de risco a fim de subsidiar processos decisórios;
# XIV - adotar indicadores específicos para monitorar suas ações em relação aos direitos humanos; e
# XV - adotar iniciativas públicas e acessíveis de transparência e divulgação das políticas, do código de conduta e
# dos mecanismos de governança.
# Art. 7º Compete às empresas garantir condições decentes de trabalho, por meio de ambiente produtivo, com
# remuneração adequada, em condições de liberdade, equidade e segurança, com iniciativas para:
# I - manter ambientes e locais de trabalho acessíveis às pessoas com deficiência, mesmo em áreas ou atividades
# onde não há atendimento ao público, a fim de que tais pessoas encontrem, no ambiente de trabalho, as condições de
# acessibilidade necessárias ao desenvolvimento pleno de suas atividades;
# II - observar os direitos de seus colaboradores de:
# a) se associar livremente;
# b) afiliar-se a sindicatos de trabalhadores;
# c) participar dos conselhos de trabalho;
# d) envolver-se em negociações coletivas;
# e) receber os benefícios previstos em lei, incluídos os repousos legais; e
# f) não exceder a jornada de trabalho legal;
# III - manter compromisso com as políticas de erradicação do trabalho análogo à escravidão e garantir ambiente de
# trabalho saudável e seguro;
# IV - não manter relações comerciais ou relações de investimentos, seja de subcontratação, seja de aquisição de
# bens e serviços, com empresas ou pessoas que violem os direitos humanos;
# da empresa e com a atribuição de rever o programa periodicamente;
# VIII - estabelecer procedimentos de controle interno e de verificação de aplicabilidade do programa de integridade,
# inclusive com a apresentação de relatórios frequentes e a publicação de demonstrações financeiras;
# IX - instituir processos internos que permitam investigações para atender prontamente às denúncias de
# comportamentos antiéticos, de forma a garantir que os fatos sejam identificados e averiguados com credibilidade, de
# forma rigorosa, independente e analítica e que os culpados sejam devidamente responsabilizados, admitidas a
# advertência e a demissão; e
# X - publicar anualmente as ações realizadas para promoção da integridade e controle de corrupção.
# Art. 11. É responsabilidade das empresas adotar medidas de garantia de transparência ativa, com divulgação de
# informações relevantes, de documentos acessíveis às partes interessadas, quanto aos mecanismos de proteção de
# direitos humanos e de prevenção e de reparação de violações de direitos humanos na cadeia produtiva, com ênfase
# para:
# I - divulgação suplementar periódicas de informações, por meio de informativos anuais que destaquem as ações
# empresariais realizadas, especialmente quanto:
# a) ao sistema de auditoria interna;
# b) ao sistema de gestão de risco; e
# c) ao cumprimento das normas de proteção de direitos humanos, das normas de prevenção e reparação de
# possíveis violações de direitos humanos;
# II - conscientização dos funcionários acerca das políticas empresariais, por meio de divulgação adequada de
# informação e de programas de formação contínua, de modo a garantir o acesso à informação e promover a atuação
# completa no processo produtivo e sem falhas, que resulte em violações aos direitos humanos; e
# III - quando solicitado, fornecimento aos consumidores, por meio de acesso rápido e eficaz, sem custos ou
# encargos desnecessários, de informações referentes à compatibilidade das atividades empresariais, do processo de
# produção ou do fornecimento de serviços com os direitos humanos.
# Art. 12. Compete às empresas adotar iniciativas para a sustentabilidade ambiental, tais como:
# I - ter conhecimento dos aspectos e dos impactos ambientais causados por suas atividades, seus produtos e seus
# serviços;
# II - desenvolver programas com objetivos, metas e ações de controle necessárias, vinculadas aos Objetivos do
# Desenvolvimento Sustentável da Organização das Nações Unidas, suficientes para evitar danos e causar menor impacto
# sobre recursos naturais como flora, fauna, ar, solo, água e utilizar, de forma sustentável, os recursos materiais;
# III - divulgar as informações de que trata o inciso I do de forma transparente, especialmente para grupos
# diretamente impactados;
# IV - utilizar bens e serviços que não gerem resíduos, poluição ou contaminação ou que gerem a menor quantidade
# de resíduos e efluentes possível;
# V - estabelecer programa de gestão de resíduos sólidos que seja socialmente inclusivo e participativo, que vise a
# não geração, à redução, à reutilização, à reciclagem, ao tratamento e à disposição final;
# VI - considerar a substituição de materiais que resultem em resíduos mais agressivos por materiais
# ambientalmente mais adequados;
# VII - adotar medidas para conferir mais eficiência às operações, a fim de reduzir emissões de gases de efeito
# estufa, de modo a contribuir com o combate às mudanças climáticas;
# 14/10/2025, 13:45
# D9571
# www.planalto.gov.br/ccivil_03/_ato2015-2018/2018/decreto/D9571.htm
# 6/10
# VIII - priorizar fontes de energia limpa e controlar e reduzir o consumo de energia elétrica;
# IX - priorizar materiais, tecnologias e matérias-primas biossustentáveis de origem local;
# X - utilizar produtos recicláveis ou que tenham maior vida útil e menor custo de manutenção do bem ou da obra;
# XI - respeitar as singularidades de cada território e o aproveitamento sustentável das potencialidades e recursos
# locais e regionais; e
# XII - incentivar fornecedores, trabalhadores e colaboradores a estabelecer diálogo permanente com as
planalto.gov.br/ccivil_03/_ato2015-2018/2018/decreto/D9571.htm\n7/10\nXII - fortalecer as ações de fiscalização na hipótese de infração de direitos trabalhistas e ambientais.',
#  'Art.',
#  '14.',
#  'Compete à administração pública incentivar que as empresas estabeleçam ou participem de mecanismos\nde denúncia e reparação efetivos e eficazes, que permitam propor reclamações e reparar violações dos direitos humanos\nrelacionadas com atividades empresariais, com ênfase para:\nI - disponibilizar mecanismos para o monitoramento e a solução de controvérsias de impactos e violações\ndecorrentes de suas atividades ou suas operações, por meio de canais de denúncia à disposição das pessoas e\ncomunidades afetadas;\nII - disponibilizar canal de denúncias direto para que as pessoas e as comunidades possam expressar suas\npreocupações em relação ao impacto adverso dos negócios em seus direitos;\nIII - facilitar o pedido de informações e o acesso por parte das comunidades atingidas e do entorno e:\na) comprometer-se com o combate aos entraves para produção de provas por parte das vítimas e dos atingidos e\ncontribuir com as investigações;\nb) dar clareza e visibilidade à sua estrutura interna e à estrutura do grupo econômico do qual faça parte; e\nc) adotar compromissos públicos de não retaliação de comunidades e de pessoas que denunciem violações ou\nrisco de violações de direitos humanos relacionadas com a empresa, considerada a sua dependência econômica;\nIV - reparar, de modo integral, as pessoas e as comunidades atingidas.',
#  'Art.',
#  '15.',
#  'A reparação integral de que trata o inciso IV do do art.',
#  '14 poderá incluir as seguintes medidas,\nexemplificativas e passíveis de aplicação, que poderão ser cumulativas:\nI - pedido público de desculpas;\nII - restituição;\nIII - reabilitação;\nIV - compensações econômicas ou não econômicas;\nV - sanções punitivas, como multas, sanções penais ou sanções administrativas; e\nVI - medidas de prevenção de novos danos como liminares ou garantias de não repetição.',
#  'Parágrafo único.',
#  'Os procedimentos de reparação serão claros e transparentes em suas etapas, amplamente\ndivulgados para todas as partes interessadas, com garantia da imparcialidade, da equidade de tratamento entre os\nindivíduos e serem passíveis de monitoramento de sua efetividade a partir de indicadores quantitativos e qualitativos de\ndireitos humanos.',
#  'CAPÍTULO V\nDA IMPLEMENTAÇÃO, DO MONITORAMENTO E DA AVALIAÇÃO DAS DIRETRIZES NACIONAIS SOBRE EMPRESAS\nE DIREITOS HUMANOS\nArt.',
#  '16.',
#  'O Ministério dos Direitos Humanos instituirá o Comitê de Acompanhamento e Monitoramento das Diretrizes\nNacionais sobre Empresas e Direitos Humanos, com as atribuições de implementar, monitorar e avaliar a execução e o\ncumprimento do disposto neste Decreto.',
#  'Art.',
#  '17.',
#  'Caberá ao Comitê de Acompanhamento e Monitoramento das Diretrizes Nacionais sobre Empresas e\nDireitos Humanos:\nI - elaborar plano de ação anual, com vistas a concretizar as Diretrizes, que será editado em ato do Ministro de\nEstado dos Direitos Humanos;\nII - elaborar estudos com a participação da sociedade civil, das instituições acadêmicas e de outros atores, com\nvistas ao aprimoramento das políticas públicas e da legislação e à adoção de planos destinados à proteção e à promoção\ndo respeito aos direitos humanos pelas empresas;\nIII - conduzir os processos de consulta pública para aprimoramento das Diretrizes e formalização dos planos de\ntrabalho;\nIV - propor ações referenciais em direitos humanos para subsidiar a atuação das empresas estatais e privadas;\nV - promover a articulação entre os órgãos e as entidades da administração pública, o setor privado, as instituições\nacadêmicas e as organizações da sociedade civil para a implementação das Diretrizes;\n14/10/2025, 13:45\nD9571\nwww.planalto.gov.br/ccivil_03/_ato2015-2018/2018/decreto/D9571.ht
planalto.gov.br/ccivil_03/_ato2015-2018/2018/decreto/D9571.htm\n9/10\nArt.',
#  '19.',
#  'Este Decreto entra em vigor na data de sua publicação.',
#  'Brasília, 21 de novembro de 2018; 197º da Independência e 130º da República.',
#  'RODRIGO MAIA\nGustavo do Vale Rocha\nEste texto não substitui o publicado no DOU de 22.11.2018\n*\n14/10/2025, 13:45\nD9571\nwww.planalto.gov.br/ccivil_03/_ato2015-2018/2018/decreto/D9571.htm\n10/10']

# %%
from deep_translator import GoogleTranslator, single_detection
tokenized_44 = sent_tokenize(text_44)

# %%
translated_sentences = [
    GoogleTranslator(source='pt', target='en').translate(tt)
    for tt in tokenized_44
]

# Pin it back together as one text
translated_text_44 = ' '.join(translated_sentences)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 from deep_translator import GoogleTranslator, single_detection
#       2 tokenized_44 = sent_tokenize(text_44)
# ----> 4 translated_sentences = [
#       5     GoogleTranslator(source='pt', target='en').translate(tt)
#       6     for tt in tokenized_44
#       7 ]
#       9 # Pin it back together as one text
#      10 translated_text_44 = ' '.join(translated_sentences)
#
# Cell In[14], line 5, in <listcomp>(.0)
#       1 from deep_translator import GoogleTranslator, single_detection
#       2 tokenized_44 = sent_tokenize(text_44)
#       4 translated_sentences = [
# ----> 5     GoogleTranslator(source='pt', target='en').translate(tt)
#       6     for tt in tokenized_44
#       7 ]
#       9 # Pin it back together as one text
#      10 translated_text_44 = ' '.join(translated_sentences)
#
# File ~/Library/Caches/pypoetry/virtualenvs/law-comparisons-9i-3jzyC-py3.10/lib/python3.10/site-packages/deep_translator/google.py:67, in GoogleTranslator.translate(self, text, **kwargs)
#      64 if self.payload_key:
#      65     self._url_params[self.payload_key] = text
# ---> 67 response = requests.get(
#      68     self._base_url, params=self._url_params, proxies=self.proxies
#      69 )
#      70 if response.status_code == 429:
#      71     raise TooManyRequests()
#
# File ~/Library/Caches/pypoetry/virtualenvs/law-comparisons-9i-3jzyC-py3.10/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/law-comparisons-9i-3jzyC-py3.10/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/law-comparisons-9i-3jzyC-py3.10/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Caches/pypoetry/virtualenvs/law-comparisons-9i-3jzyC-py3.10/lib/python3.10/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/Library/Caches/pypoetry/virtualenvs/law-comparisons-9i-3jzyC-py3.10/lib/python3.10/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~/Library/Caches/pypoetry/virtualenvs/law-comparisons-9i-3jzyC-py3.10/lib/python3.10/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/Library/Caches/pypoetry/virtualenvs/law-comparisons-9i-3jzyC-py3.10/lib/python3.10/site-packages/urllib3/response.py:1088, in HTTPResponse.stream(self, amt, decode_content)
#    1072 """
#    1073 A generator wrapper for the read() method. A call will block until
#    1074 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1085     'content-encoding' header.
#    1086 """
#    1087 if self.chunked and self.supports_chunked_reads():
# -> 1088     yield from self.read_chunked(amt, decode_content=decode_content)
#    1089 else:
#    1090     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~/Library/Caches/pypoetry/virtualenvs/law-comparisons-9i-3jzyC-py3.10/lib/python3.10/site-packages/urllib3/response.py:1248, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1245     amt = None
#    1247 while True:
# -> 1248     self._update_chunk_length()
#    1249     if self.chunk_left == 0:
#    1250         break
#
# File ~/Library/Caches/pypoetry/virtualenvs/law-comparisons-9i-3jzyC-py3.10/lib/python3.10/site-packages/urllib3/response.py:1167, in HTTPResponse._update_chunk_length(self)
#    1165 if self.chunk_left is not None:
#    1166     return None
# -> 1167 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1168 line = line.split(b";", 1)[0]
#    1169 try:
#
# File /opt/homebrew/Cellar/python@3.10/3.10.18/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:717, in SocketIO.readinto(self, b)
#     715 while True:
#     716     try:
# --> 717         return self._sock.recv_into(b)
#     718     except timeout:
#     719         self._timeout_occurred = True
#
# File /opt/homebrew/Cellar/python@3.10/3.10.18/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/homebrew/Cellar/python@3.10/3.10.18/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from pprint import pprint
pprint(translated_text_44)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 from pprint import pprint
# ----> 2 pprint(translated_text_44)
#
# NameError: name 'translated_text_44' is not defined

# %%
def chinese_sent_tokenize(text):
    """
    Tokenize Chinese text into sentences using Chinese punctuation marks.
    Chinese uses different punctuation: 。(period), ！(exclamation), ？(question mark)
    Also handles some English-style punctuation mixed in Chinese text.
    """
    # Replace Chinese punctuation with placeholder + newline for splitting
    text = re.sub(r'([。！？!?；])', r'\1\n', text)
    
    # Split by newlines and filter out empty strings
    sentences = [s.strip() for s in text.split('\n') if s.strip()]
    
    # Filter out very short "sentences" that are likely headers or page numbers
    sentences = [s for s in sentences if len(s) > 3]
    
    return sentences

def smart_sent_tokenize(text, language='auto'):
    """
    Tokenize text into sentences based on language.
    For Chinese (zh), uses Chinese punctuation.
    For other languages, uses NLTK's sent_tokenize.
    """
    if language == 'zh' or language == 'zh-CN' or language == 'zh-TW':
        return chinese_sent_tokenize(text)
    else:
        # Use NLTK for English and other Latin-script languages
        return sent_tokenize(text)

# %%
from deep_translator import single_detection

# Detect language of text
lang = single_detection(text_44, api_key='70013dac7b8673080e5edc9bae911672')
print(lang)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 from deep_translator import single_detection
#       3 # Detect language of text
# ----> 4 lang = single_detection(text_44, api_key='70013dac7b8673080e5edc9bae911672')
#       5 print(lang)
#
# NameError: name 'text_44' is not defined

# %%
def map_language_code(lang):
    """
    Map language codes from detection API to GoogleTranslator format.
    Detection API returns 'zh', but GoogleTranslator needs 'zh-CN' or 'zh-TW'.
    """
    language_map = {
        'zh': 'zh-CN',  # Default Chinese to Simplified
        'zh-cn': 'zh-CN',
        'zh-tw': 'zh-TW',
    }
    return language_map.get(lang.lower(), lang)

def translate_and_process(text, partial_translation=None): 
    """
    Translate text sentence by sentence, resuming from partial translation if provided.
    Returns tuple: (translated_text, is_complete)
    """
    # Handle empty or invalid text
    if not text or not isinstance(text, str) or len(text.strip()) == 0:
        print('  ⚠️  Empty or invalid text, skipping')
        return None, True  # Mark as complete so we don't retry empty documents
    
    # Detect language FIRST using a small sample (before tokenization)
    small_sample = text[:1000] if len(text) > 1000 else text
    detected_lang = single_detection(small_sample, api_key='70013dac7b8673080e5edc9bae911672')
    print('language detected: ', detected_lang)
    
    # Map the language code to GoogleTranslator format
    lang = map_language_code(detected_lang)
    if lang != detected_lang:
        print(f'  🔄 Mapped language code: {detected_lang} -> {lang}')
    
    if lang == 'en':
        return text, True  # Already in English, return original
    
    # Use language-aware tokenization (handles Chinese properly)
    # Use the original detected_lang for tokenization logic
    tokenized_text = smart_sent_tokenize(text, detected_lang)
    print(f'  📝 Text split into {len(tokenized_text)} sentences')
    
    # Figure out where to resume from
    translated_sentences = []
    start_idx = 0
    
    if partial_translation:
        # Count how many sentences were already translated by tokenizing the partial translation
        # The partial_translation is in ENGLISH, so tokenize it with 'en', not the source language
        partial_tokenized = smart_sent_tokenize(partial_translation, 'en')
        start_idx = len(partial_tokenized)
        
        # Keep the already-translated text as-is
        translated_sentences = partial_tokenized.copy()
        
        print(f'  📍 Resuming from sentence {start_idx + 1}/{len(tokenized_text)} ({start_idx} already translated)')
    
    # Translate remaining sentences one by one
    try:
        for i in range(start_idx, len(tokenized_text)):
            sentence = tokenized_text[i].strip()
            
            # Skip empty sentences
            if not sentence:
                continue
                
            print(f"    ➡️  Translating sentence {i+1}/{len(tokenized_text)} ...", end=" ", flush=True)
            
            try:
                translated = GoogleTranslator(source=lang, target='en').translate(sentence)
                translated_sentences.append(translated)
                print("done.")
            except Exception as sent_error:
                error_msg = str(sent_error)
                
                # ALWAYS print the actual error so we can debug
                print(f"ERROR: {error_msg}")
                
                # Check if it's a network/connection error
                if any(keyword in error_msg for keyword in ['HTTPS', 'Connection', 'HTTPError', 'timeout', 'Network']):
                    # Network error - stop here and mark as incomplete so we retry later
                    print(f"connection error!")
                    raise sent_error  # Raise to trigger partial save and retry
                else:
                    # Translation error (special characters, can't translate, etc.)
                    # Keep the original Portuguese text for this sentence
                    print(f"translation error - keeping original")
                    translated_sentences.append(sentence)
            
        # All sentences processed - filter out any None values before joining
        filtered_sentences = [s for s in translated_sentences if s is not None]
        final_text = ' '.join(filtered_sentences)
        return final_text, True
        
    except Exception as e:
        # Network error or unexpected issue - save partial progress
        error_msg = str(e)
        if any(keyword in error_msg for keyword in ['HTTPS', 'Connection', 'HTTPError', 'timeout', 'Network']):
            print(f'\n  🌐 Network issue at sentence {i + 1}/{len(tokenized_text)} - saving partial progress')
        else:
            print(f'\n  ⚠️  Unexpected error at sentence {i + 1}/{len(tokenized_text)}: {str(e)[:100]}')
        
        # Filter out None values before joining
        filtered_sentences = [s for s in translated_sentences if s is not None]
        partial_text = ' '.join(filtered_sentences) if filtered_sentences else None
        return partial_text, False

# %%
import time
from requests.exceptions import RequestException, ConnectionError, HTTPError

def translate_with_retry(text, partial_translation=None, max_retries=5, delay=5):
    """Translate with automatic retry on network errors, supporting partial progress"""
    for attempt in range(max_retries):
        try:
            translated_text, is_complete = translate_and_process(text, partial_translation)
            return translated_text, is_complete
        except (RequestException, ConnectionError, HTTPError, Exception) as e:
            print(f"  ⚠️  Error (attempt {attempt + 1}/{max_retries}): {str(e)[:100]}")
            if attempt < max_retries - 1:
                print(f"  ⏳ Waiting {delay} seconds before retry...")
                time.sleep(delay)
            else:
                print(f"  ❌ Failed after {max_retries} attempts")
                return None, False

def is_translation_complete(original_text, translated_text):
    """Check if translation is complete by comparing sentence counts"""
    if not original_text or not isinstance(original_text, str):
        return True  # Can't translate invalid text
    if not translated_text or not isinstance(translated_text, str):
        return False  # No translation exists
    
    # Detect language of original text for proper tokenization
    small_sample = original_text[:1000] if len(original_text) > 1000 else original_text
    lang = single_detection(small_sample, api_key='70013dac7b8673080e5edc9bae911672')
    
    # Tokenize both texts using the detected language
    original_sentences = smart_sent_tokenize(original_text, lang)
    translated_sentences = smart_sent_tokenize(translated_text, 'en')  # Translations are in English
    
    # Translation is complete if at least 90% of sentences are translated
    # (allowing some wiggle room for sentence splitting differences)
    completion_ratio = len(translated_sentences) / len(original_sentences)
    return completion_ratio >= 0.9

def process_dataframe_with_checkpoints(df, save_path='b_df_checkpoint.csv'):
    """
    Process dataframe with automatic saving, supporting partial sentence-level progress.
    Uses df for text content, checkpoint only for translation status.
    """
    
    # Keep the original df with fresh text data
    working_df = df.copy()
    
    # Load existing translations from checkpoint (if available)
    try:
        checkpoint_df = pd.read_csv(save_path, escapechar='\\')
        print(f"📂 Loaded checkpoint from {save_path}")
        
        # Merge only the 'translated' column from checkpoint
        if 'translated' in checkpoint_df.columns:
            # Create a mapping of file -> translated text
            translation_map = dict(zip(checkpoint_df['file'], checkpoint_df['translated']))
            working_df['translated'] = working_df['file'].map(translation_map)
        else:
            working_df['translated'] = None
            
    except (FileNotFoundError, pd.errors.EmptyDataError):
        print("🆕 Starting fresh (no checkpoint found or checkpoint corrupted)")
        working_df['translated'] = None

    for idx, row in working_df.iterrows():
        text = row['text']
        existing_translation = row.get('translated') if pd.notna(row.get('translated')) else None
        
        # Check if translation is complete
        if existing_translation and is_translation_complete(text, existing_translation):
            print(f"\n⏭️  Skipping file: {row['file']} (already translated)")
            continue

        print(f"\n🔄 Processing file: {row['file']}")
        
        # Skip .DS_Store and other non-PDF files
        if not row['file'].endswith('.pdf'):
            print(f"  ⏭️  Skipping non-PDF file")
            working_df.at[idx, 'translated'] = None
            continue

        # Try to translate (or continue from partial)
        translated, is_complete = translate_with_retry(text, existing_translation)

        if translated:
            # Save whatever progress we have (complete or partial)
            working_df.at[idx, 'translated'] = translated
            working_df.to_csv(save_path, index=False, escapechar='\\', doublequote=False)

            if is_complete:
                print(f"  ✅ Complete translation saved!")
            else:
                print(f"  💾 Partial translation saved (will continue next time)")
        else:
            # No progress made at all
            print(f"  ❌ No translation progress - will retry next time")
            if existing_translation is None:
                working_df.at[idx, 'translated'] = None
                working_df.to_csv(save_path, index=False, escapechar='\\', doublequote=False)

        # Small delay between requests to avoid rate limiting
        time.sleep(1)

    print("\n🎉 All done!")
    return working_df

# %%
# Run it
b_df = process_dataframe_with_checkpoints(b_df, save_path='b_df_checkpoint.csv')
# Out:
# 📂 Loaded checkpoint from b_df_checkpoint.csv
#
# ⏭️  Skipping file: 49.pdf (already translated)
#
# ⏭️  Skipping file: 61.pdf (already translated)
#
# ⏭️  Skipping file: 75.pdf (already translated)
#
# ⏭️  Skipping file: 74.pdf (already translated)
#
# ⏭️  Skipping file: 60.pdf (already translated)
#
# ⏭️  Skipping file: 48.pdf (already translated)
#
# ⏭️  Skipping file: 62.pdf (already translated)
#
# ⏭️  Skipping file: 63.pdf (already translated)
#
# ⏭️  Skipping file: 73.pdf (already translated)
#
# ⏭️  Skipping file: 67.pdf (already translated)
#
# ⏭️  Skipping file: 9.pdf (already translated)
#
# 🔄 Processing file: .DS_Store
#   ⏭️  Skipping non-PDF file
#     ➡️  Translating sentence 71/77 ... done.
#     ➡️  Translating sentence 72/77 ... done.
#     ➡️  Translating sentence 73/77 ... done.
#     ➡️  Translating sentence 74/77 ... done.
#     ➡️  Translating sentence 75/77 ... done.
#     ➡️  Translating sentence 76/77 ... done.
#     ➡️  Translating sentence 77/77 ... done.
#   ✅ Complete translation saved!
#
# 🎉 All done!

# %%
b_df
# Out:
#       file                                               text  \
# 0   49.pdf  \nPublicado em: 14/06/2019 | Edição: 114 | Seç...
# 1   61.pdf  \nPublicado em: 05/06/2020 | Edição: 107-A | S...
# 2   75.pdf   \nPresidencia da Republica \nCasa Civil \nSub...
# 3   74.pdf  archive.today\nwebpage capture\n https://www.j...
# 4   60.pdf  \n\n\n\nRevogado pelo Decreto nº 11.964, de 20...
# ..     ...                                                ...
# 68   3.pdf  \n \nPublicada no DOU nº 1, de 2 de janeiro de...
# 69  51.pdf  \n\n\n\n \nAprova o Programa Nacional de Direi...
# 70   2.pdf    \n \n  \n(D.O.U. de 01/11/00)  \n  \n  \nO D...
# 71  50.pdf   \nResolução nº 3.896, de 17 de agosto de 2010...
# 72  44.pdf  \n\n\n\nRevogado pelo Decreto nº 11.772, de 20...
#
#                                            translated
# 0   Published on: 06/14/2019 | Edition: 114 | Sect...
# 1   Published on: 06/05/2020 | Edition: 107-A | Se...
# 2   Presidency of the Republic \nCivil House \nDep...
# 3   archive.today\nweb page capture\n https://www....
# 4   Revoked by Decree No. 11,964, of 2024\nText fo...
# ..                                                ...
# 68  Published in DOU nº 1, of January 2, 2007, Sec...
# 69  Approves the National Human Rights Program -\n...
# 70  (D.O.U. of 01/11/00)  \n  \n  \nTHE GENERAL DI...
# 71  Resolution No. 3,896, of August 17, 2010 \n1 \...
# 72  Repealed by Decree No. 11,772, of 2023\nText f...
#
# [73 rows x 3 columns]

# %% [markdown]
# _______

# %% [markdown]
# ### Mandarin translation

# %%
c_df = load_files(china_folder)
# Out:
# Loading files from china:   0%|          | 0/45 [00:00<?, ?it/s]
# MuPDF error: format error: No default Layer config

# %%
# Test: Verify Chinese tokenization is working properly
sample_chinese = c_df[c_df['file'] == '13.pdf']
if not sample_chinese.empty:
    text = sample_chinese.iloc[0]['text']
    print(f"Text length: {len(text)} characters")
    print(f"First 300 chars:\n{text[:300]}")
    
    # Test old way (NLTK - doesn't work for Chinese)
    print(f"\n❌ Old way (NLTK sent_tokenize): {len(sent_tokenize(text))} sentences")
    
    # Test new way (language-aware)
    chinese_sentences = smart_sent_tokenize(text, 'zh')
    print(f"✅ New way (Chinese-aware tokenization): {len(chinese_sentences)} sentences")
    print(f"\nFirst 3 sentences:")
    for i, sent in enumerate(chinese_sentences[:3]):
        print(f"  {i+1}. {sent[:80]}...")
else:
    print("File not found")
# Out:
# Text length: 27910 characters
# First 300 chars:
# 全国重要生态系统保护和修复重大工程
# 总体规划（2021—2035 年）
# 二〇二〇年五月
# I
# 目
# 录
# 前
# 言.......................................................................................... 1
# 第一章
# 生态保护和修复面临的形势......................................3
# 一、我国生态保护和修复工作成效
# （一）森林资源总量持续快速增长.................................... 3
# （二）草原生态系统恶化趋势得到遏制...........
#
# ❌ Old way (NLTK sent_tokenize): 1 sentences
# ✅ New way (Chinese-aware tokenization): 1208 sentences
#
# First 3 sentences:
#   1. 全国重要生态系统保护和修复重大工程...
#   2. 总体规划（2021—2035 年）...
#   3. 二〇二〇年五月...

# %%
c_df = process_dataframe_with_checkpoints(c_df, save_path='c_df_checkpoint.csv')
# Out:
# 📂 Loaded checkpoint from c_df_checkpoint.csv
#
# ⏭️  Skipping file: 49.pdf (already translated)
#
# ⏭️  Skipping file: 48.pdf (already translated)
#
# ⏭️  Skipping file: 9.pdf (already translated)
#
# 🔄 Processing file: .DS_Store
#   ⏭️  Skipping non-PDF file
#
# ⏭️  Skipping file: 8.pdf (already translated)
#
# ⏭️  Skipping file: 29.pdf (already translated)
#
# 🔄 Processing file: 14.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# ⏭️  Skipping file: 28.pdf (already translated)
#
# ⏭️  Skipping file: 10.pdf (already translated)
#
# ⏭️  Skipping file: 38.pdf (already translated)
#
# ⏭️  Skipping file: 39.pdf (already translated)
#
# ⏭️  Skipping file: 11.pdf (already translated)
#
# 🔄 Processing file: ~$21.pdf.docx
#   ⏭️  Skipping non-PDF file
#
# ⏭️  Skipping file: 13.pdf (already translated)
#
# ⏭️  Skipping file: 12.pdf (already translated)
#
# ⏭️  Skipping file: 23.pdf (already translated)
#
# ⏭️  Skipping file: 34.pdf (already translated)
#
# ⏭️  Skipping file: 20.pdf (already translated)
#
# ⏭️  Skipping file: 21.pdf (already translated)
#
# ⏭️  Skipping file: 35.pdf (already translated)
#
# ⏭️  Skipping file: 31.pdf (already translated)
#
# ⏭️  Skipping file: 25.pdf (already translated)
#
# ⏭️  Skipping file: 19.pdf (already translated)
#
# ⏭️  Skipping file: 18.pdf (already translated)
#
# ⏭️  Skipping file: 24.pdf (already translated)
#
# ⏭️  Skipping file: 30.pdf (already translated)
#
# ⏭️  Skipping file: 26.pdf (already translated)
#
# ⏭️  Skipping file: 32.pdf (already translated)
#
# ⏭️  Skipping file: 33.pdf (already translated)
#
# ⏭️  Skipping file: 27.pdf (already translated)
#
# ⏭️  Skipping file: 40.pdf (already translated)
#
# ⏭️  Skipping file: 6.pdf (already translated)
#
# ⏭️  Skipping file: 7.pdf (already translated)
#
# ⏭️  Skipping file: 41.pdf (already translated)
#
# ⏭️  Skipping file: 5.pdf (already translated)
#
# ⏭️  Skipping file: 43.pdf (already translated)
#
# ⏭️  Skipping file: 42.pdf (already translated)
#
# ⏭️  Skipping file: 4.pdf (already translated)
#
# ⏭️  Skipping file: 46.pdf (already translated)
#
# 🔄 Processing file: 1.pdf
# language detected:  zh
#   🔄 Mapped language code: zh -> zh-CN
#   📝 Text split into 347 sentences
#   📍 Resuming from sentence 261/347 (260 already translated)
#     ➡️  Translating sentence 261/347 ... done.
#     ➡️  Translating sentence 262/347 ... done.
#     ➡️  Translating sentence 263/347 ... done.
#     ➡️  Translating sentence 264/347 ... done.
#     ➡️  Translating sentence 265/347 ... done.
#     ➡️  Translating sentence 333/347 ... done.
#     ➡️  Translating sentence 334/347 ... done.
#     ➡️  Translating sentence 335/347 ... done.
#     ➡️  Translating sentence 336/347 ... done.
#     ➡️  Translating sentence 337/347 ... done.
#     ➡️  Translating sentence 338/347 ... done.
#     ➡️  Translating sentence 339/347 ... done.
#     ➡️  Translating sentence 340/347 ... done.
#     ➡️  Translating sentence 341/347 ... done.
#     ➡️  Translating sentence 342/347 ... done.
#     ➡️  Translating sentence 343/347 ... done.
#     ➡️  Translating sentence 344/347 ... done.
#     ➡️  Translating sentence 345/347 ... done.
#     ➡️  Translating sentence 346/347 ... done.
#     ➡️  Translating sentence 347/347 ... done.
#   ✅ Complete translation saved!
#
# ⏭️  Skipping file: 45.pdf (already translated)
#
# 🔄 Processing file: 3.pdf
#   ⚠️  Empty or invalid text, skipping
#   ❌ No translation progress - will retry next time
#
# ⏭️  Skipping file: 2.pdf (already translated)
#
# ⏭️  Skipping file: 50.pdf (already translated)
#
# ⏭️  Skipping file: 44.pdf (already translated)
#
# 🎉 All done!

# %% [markdown]
# _____

# %%
eu_df = load_files(eu_folder)
# Out:
# Loading files from eu:   0%|          | 0/100 [00:00<?, ?it/s]

# %%
eu_df = process_dataframe_with_checkpoints(eu_df, save_path='eu_df_checkpoint.csv')
# Out:
# 🆕 Starting fresh (no checkpoint found or checkpoint corrupted)
#
# 🔄 Processing file: 49.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 61.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 75.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 74.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 60.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 48.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 89.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 76.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 62.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 63.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 77.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 88.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 98.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 73.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 67.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 9.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: .DS_Store
#   ⏭️  Skipping non-PDF file
#
# 🔄 Processing file: 8.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 66.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 72.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 99.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 64.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 70.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 58.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 41b.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 59.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 71.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 65.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 16.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 17.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 29.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 15.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 14.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 28.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 10.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 38.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 39.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 11.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 13.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 12.pdf
#   ⚠️  Error (attempt 1/5): HTTPSConnectionPool(host='ws.detectlanguage.com', port=443): Max retries exceeded with url: /0.2/det
#   ⏳ Waiting 5 seconds before retry...
#   ⚠️  Error (attempt 2/5): HTTPSConnectionPool(host='ws.detectlanguage.com', port=443): Max retries exceeded with url: /0.2/det
#   ⏳ Waiting 5 seconds before retry...
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 23.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 37.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 36.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 22.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 34.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 20.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 21.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 35.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 31.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 25.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 19.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 18.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 24.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 30.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 26.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 32.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 33.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 27.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 83.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 97.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 68.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 40.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 54.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 6.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 55.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 7.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 41.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 69.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 96.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 82.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 94.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 80.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 5.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 57.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 43.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 42.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 4.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 56.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 81.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 95.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 91.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 85.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 52.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 46.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 47.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 53.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 1.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 84.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 90.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 86.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 92.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 45.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 3.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 51.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 79.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 78.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 2.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 50.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 44.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🔄 Processing file: 93.pdf
# language detected:  en
#   ✅ Complete translation saved!
#
# 🎉 All done!

# %% [markdown]
# _____

# %%
c_df
# Out:
#              file                                               text  \
# 0          49.pdf  附件： \n \n \n国家应对气候变化规划（ 年）\n\n\n\n\n\n\n\n\n\n...
# 1          48.pdf  on the Prevention and Gntrol of Air Pollution ...
# 2           9.pdf  POLICY UPDATE\n\n       COMMUNICATIONS@THEICCT...
# 3       .DS_Store                                                NaN
气体统计核算体系...............................................41 \n第二节 加强队伍建设.......................................................................41 \n第三节 加强教育培训和舆论引导...................................................42 \n第十章深化国际交流与合作 \n第一节 推动建立公平合理的国际气候制度...................................43 \n第二节 加强与国际组织、发达国家合作.......................................44 \n第三节 大力开展南南合作...............................................................45 \n第十一章组织实施 \n第一节 加强组织领导.......................................................................45 \n第二节 强化统筹协调...................................................................... ...

# %%
import pandas as pd

# Load the checkpoint files
b_df = pd.read_csv('b_df_checkpoint.csv', escapechar='\\')  # Brazilian docs
c_df = pd.read_csv('c_df_checkpoint.csv', escapechar='\\')  # Chinese docs
eu_df = pd.read_csv('eu_df_checkpoint.csv', escapechar='\\') # EU docs (already English)

# Each dataframe has columns: 'file', 'text' (original), 'translated' (English)

# %%
# Access translated text for a specific file
translated_text = b_df[b_df['file'] == '44.pdf']['translated'].iloc[0]

# Get all translated documents
all_translations = b_df['translated'].tolist()

# Create a combined dataframe with all documents
combined_df = pd.concat([
    b_df.assign(source='Brazil'),
    c_df.assign(source='China'),
    eu_df.assign(source='EU')
], ignore_index=True)

# Work with just the English versions
combined_df['english_text'] = combined_df['translated'].fillna(combined_df['text'])

# %%
# Create final datasets
data_dir = 'data/'

for df, name in [(b_df, 'brazil'), (c_df, 'china'), (eu_df, 'eu')]:
    output = df[['file', 'translated']].copy()
    output.columns = ['file', 'text']
    output.to_csv(f'{data_dir}{name}_df.csv', index=False)

# %%
combined_df
# Out:
#        file                                               text  \
# 0    49.pdf  \nPublicado em: 14/06/2019 | Edição: 114 | Seç...
# 1    61.pdf  \nPublicado em: 05/06/2020 | Edição: 107-A | S...
# 2    75.pdf   \nPresidencia da Republica \nCasa Civil \nSub...
# 3    74.pdf  archive.today\nwebpage capture\n https://www.j...
# 4    60.pdf  \n\n\n\nRevogado pelo Decreto nº 11.964, de 20...
# ..      ...                                                ...
# 213  78.pdf  DECISIONS \n\n\n\n(notified under document C(2...
# 214   2.pdf  ELI: http://data.europa.eu/eli/reg/2024/795/oj...
# 215  50.pdf  28.8.2014   \nEN\nOfficial Journal of the Euro...
# 216  44.pdf  I\n(Legislative acts)\nDIRECTIVES\n\n\n\n\nTHE...
# 217  93.pdf  I \n(Legislative acts) \nREGULATIONS\n\n\n\n\n...
#
#                                             translated  source  \
# 0    Published on: 06/14/2019 | Edition: 114 | Sect...  Brazil
# 1    Published on: 06/05/2020 | Edition: 107-A | Se...  Brazil
# 2    Presidency of the Republic \nCivil House \nDep...  Brazil
# 3    archive.today\nweb page capture\n https://www....  Brazil
# 4    Revoked by Decree No. 11,964, of 2024\nText fo...  Brazil
# ..                                                 ...     ...
# 213  DECISIONS \n\n\n\n(notified under document C(2...      EU
# 214  ELI: http://data.europa.eu/eli/reg/2024/795/oj...      EU
# 215  28.8.2014   \nEN\nOfficial Journal of the Euro...      EU
# 216  I\n(Legislative acts)\nDIRECTIVES\n\n\n\n\nTHE...      EU
# 217  I \n(Legislative acts) \nREGULATIONS\n\n\n\n\n...      EU
#
#                                           english_text
# 0    Published on: 06/14/2019 | Edition: 114 | Sect...
# 1    Published on: 06/05/2020 | Edition: 107-A | Se...
# 2    Presidency of the Republic \nCivil House \nDep...
# 3    archive.today\nweb page capture\n https://www....
# 4    Revoked by Decree No. 11,964, of 2024\nText fo...
# ..                                                 ...
# 213  DECISIONS \n\n\n\n(notified under document C(2...
# 214  ELI: http://data.europa.eu/eli/reg/2024/795/oj...
# 215  28.8.2014   \nEN\nOfficial Journal of the Euro...
# 216  I\n(Legislative acts)\nDIRECTIVES\n\n\n\n\nTHE...
# 217  I \n(Legislative acts) \nREGULATIONS\n\n\n\n\n...
#
# [218 rows x 5 columns]

# %% [markdown]
# _____

# %% [markdown]
# Now I have combined_df and I can embed and chunk. Then I can use an LLM to look through the chunks and extract any laws, policies, or directives that are relevant in the given country.

# %%
from transformers import AutoTokenizer
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
tokenizer = AutoTokenizer.from_pretrained("nomic-ai/nomic-embed-text-v1")

# %%
def tokenize_and_chunk(row, tokenizer, max_tokens=512, text_col='text'):
    sentences = re.split(r'(?<=[.!?]) +', row[text_col])
    chunks = []
    current_chunk = []
    current_tokens = 0

    for sentence in sentences:
        token_count = len(tokenizer.tokenize(sentence))

        if current_tokens + token_count <= max_tokens:
            current_chunk.append(sentence)
            current_tokens += token_count
        else:
            if current_chunk:
                chunk_row = row.to_dict()
                chunk_row[text_col] = ' '.join(current_chunk)
                chunks.append(chunk_row)
            current_chunk = [sentence]
            current_tokens = token_count

    if current_chunk:
        chunk_row = row.to_dict()
        chunk_row[text_col] = ' '.join(current_chunk)
        chunks.append(chunk_row)

    return chunks

# %%
print("Chunking documents...")

chunked_rows = []
for _, row in combined_df.iterrows():
    # Only chunk over the 'translated' column, but preserve 'file' and 'country' info
    translated_text = row.get('translated', None)
    if not isinstance(translated_text, str) or not translated_text.strip():
        continue  # skip rows where translated text is not a valid string
    chunk_input = row.copy()
    chunk_input['text'] = translated_text
    try:
        chunks = tokenize_and_chunk(chunk_input, tokenizer, text_col='text')
    except TypeError:
        continue  # skip this row if tokenize_and_chunk fails
    for chunk in chunks:
        # store chunk and remember source
        chunk_record = {
            'file': row.get('file', None),
            'country': row.get('source', None),
            'chunk_text': chunk['text']
        }
        chunked_rows.append(chunk_record)

chunked_df = pd.DataFrame(chunked_rows)
chunked_df = chunked_df.drop_duplicates(subset=['chunk_text']).reset_index(drop=True)
# Out:
# Chunking documents...

# %%
chunked_df
# Out:
#         file country                                         chunk_text
# 0     49.pdf  Brazil  Published on: 06/14/2019 | Edition: 114 | Sect...
# 1     49.pdf  Brazil  729, of May 11, 2018,\nsent by the ANP to the ...
# 2     49.pdf  Brazil  § 2 Annually, the ANP will publish, on its web...
# 3     49.pdf  Brazil  9º The fuel distributor must maintain, for a p...
# 4     49.pdf  Brazil  The definitive individual annual goals for 201...
# ...      ...     ...                                                ...
# 9297  44.pdf      EU  131).’\n(5) Annex IIIb to Directive 1999/62/EC...
# 9298  44.pdf      EU  If there is \nscientific evidence for a higher...
# 9299  44.pdf      EU  The parts of the network subject to congestion...
# 9300  44.pdf      EU  The resulting \ncharging structure shall be tr...
# 9301  44.pdf      EU  Congestion charge for \nother vehicle categori...
#
# [9302 rows x 3 columns]

# %% [markdown]
# ### Calling an LLM

# %%
from dotenv import load_dotenv
import openai
# Load environment variables from .env file
load_dotenv()

# Get OpenRouter API key from environment variables
OPENROUTER_API_KEY = os.getenv('OPENROUTER_API_KEY')
if not OPENROUTER_API_KEY:
    raise ValueError("Please set OPENROUTER_API_KEY in your .env file or environment variables")

# %%
client = openai.OpenAI(
    api_key=OPENROUTER_API_KEY,
    base_url="https://openrouter.ai/api/v1"
)

# %%
system_prompt = '''You are an expert in climate finance law and policy. Your task is to identify climate finance policy instruments.

# CORE DEFINITION

A climate finance policy instrument must meet ALL four criteria:

1. TYPE: Public policies (laws, regulations, guidelines, programs, investment decisions) that govern or structure financial flows at scale

2. SOURCE: Originated by public authorities (national/subnational legislators, governments, regulatory agencies, enforcement agencies, state-owned entities)

3. TARGET: Directly influences financial flows AND the behavior of:
   - Financial institutions (banks, insurers, asset managers, pension funds, etc.)
   - Financial market participants (investors, lenders, underwriters)
   - Individuals making finance-related decisions (financial advisors, fund managers)

4. PURPOSE: Explicit climate objective to materially impact:
   - Climate mitigation (reducing GHG emissions, enhancing carbon sinks)
   - Climate adaptation (reducing vulnerability, increasing resilience to climate impacts)
   - Loss and damage compensation (addressing climate-related losses)

# KEY PRINCIPLE: FINANCIAL SECTOR FOCUS

The policy must regulate HOW MONEY FLOWS in the financial system, not just regulate emissions or environmental practices directly.

Examples of FINANCIAL targets:
- Green bond standards
- Climate risk disclosure requirements for financial institutions
- ESG investment mandates for pension funds
- Green lending quotas for banks
- Climate stress testing requirements for insurers

Examples of NON-FINANCIAL targets (EXCLUDE these):
- Emissions standards for factories
- Renewable energy mandates for utilities
- Biofuel requirements for fuel producers
- Building energy efficiency codes
- Vehicle emissions regulations

# INCLUSION RULES

INCLUDE policies that:
- Are not climate-exclusive BUT have explicit purpose to materially and systematically affect climate-related financial flows
- Example: Environmental disclosure requirements for listed firms that result in climate information being provided to investors

# EXCLUSION RULES

EXCLUDE policies that:

1. Lack explicit climate/environmental purpose:
   - General consumer protection or deceptive marketing rules (even if used in climate litigation)
   - Standard financial advisor training/suitability requirements (unless they explicitly include climate considerations)

2. Target non-financial sectors:
   - Production mandates (biofuels, renewable energy quotas for producers)
   - Operational emissions standards
   - Product bans or restrictions
   - Direct subsidies to clean tech manufacturers

3. Focus primarily on non-climate environmental goals:
   - Biodiversity reserves
   - Toxic substance prohibitions
   - Air quality standards (non-GHG pollutants)
   - (Exclude even if they have indirect climate co-benefits)

# DECISION FRAMEWORK

Ask yourself:
1. Does this policy regulate the FINANCIAL SECTOR or financial decision-making?
2. Does it aim to change WHERE and HOW money is allocated?
3. Does it have an EXPLICIT climate purpose (stated in the policy)?

If NO to any question → EXCLUDE
If YES to all questions → INCLUDE
'''

# %%
def get_user_prompt(chunk):
    return f"""
You are an expert in climate finance law and policy. Your goal is to identify climate finance policy instruments. Only returned NAMED policy instruments. 

For example, if a sentence said, "The government has implemented a policy to encourage green investments", you should return nothing. If the previous sentence said, "The government has implemented the Green Investment Act", then you would return "Green Investment Act".

Even if the policy instrument is named, but there is not enough context to identify it as related to climate finance, you should return nothing.

We define climate finance policy instruments as: 

{system_prompt}

Here is the text to analyze:
{chunk}

Please identify the climate finance policy instruments in the text. Respond only with a JSON object in one of the following two formats:

If there are no climate finance policy instruments in the text, respond with:
{{
  "has_policy_instruments": false,
  "policy_instruments": []
}}

If there are climate finance policy instruments in the text, respond with:
{{
  "has_policy_instruments": true,
  "policy_instruments": ["name of instrument 1", "name of instrument 2", ...]
}}

Do not provide any reasoning or any other information. Only respond with the JSON object as specified above.
"""

# %%
chunk_1 = get_user_prompt(chunked_df['chunk_text'].iloc[0])

# %%
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": chunk_1}
    ]
)

# %%
response_slim = response.choices[0].message.content
response_slim
# Out:
# '{\n  "has_policy_instruments": false,\n  "policy_instruments": []\n}'

# %%
for i in range(10):
    print(f"Chunk {i+1}:\n{chunked_df['chunk_text'].iloc[i]}\n")
# Out:
# Chunk 1:
# Published on: 06/14/2019 | Edition: 114 | Section: 1 | Page: 44
#
#
#
# Provides for the individualization of annual compulsory targets
# to reduce greenhouse gas emissions
# for the sale of fuels, within the scope of the Policy
# National Biofuels Agency (RenovaBio). THE BOARD OF THE NATIONAL PETROLEUM, NATURAL GAS AND BIOFUELS AGENCY -
# ANP, in the exercise of the powers conferred by art. 6 of the Internal Regulations and by art. 7th of Annex I of
# Decree No. 2,455, of January 14, 1998, in view of the provisions of Law No. 9,478, of August 6,
# 1997, considering what is contained in Process nº 48610.003318/2018 and the deliberations taken in the 980th
# Board Meeting, held on June 11, 2019, resolves:
# CHAPTER I
# ANNUAL TARGETS FOR REDUCING GREENHOUSE GAS EMISSIONS
# Art. 1st The criteria for the individualization of annual compulsory targets are established
# to reduce greenhouse gas emissions for the sale of fuels
# applicable to all fuel distributors, as referred to in art. 7th of Law No. 13,576, of 26
# December 2017, and art. 5th of Decree No. 9,308, of March 15, 2018. Art. 2º The individual annual target for reducing greenhouse gases of the distributor of
# fuels will be an integer greater than zero, calculated from the multiplication of the
# distributor's market share in total emissions from fossil fuels (in fraction
# percentage) by the annual target established by the National Energy Policy Council, through the
# CNPE Resolution No. 5, of June 5, 2018. Single paragraph. The individual annual goal:
# I - will be established in Decarbonization Credit units (CBIO), based on the targets
# annual compulsory obligations defined by CNPE Resolution No. 5, of June 5, 2018, or another that may be
# replace it;
# II - may be reviewed in accordance with art. 4th of CNPE Resolution No. 5, of 2018, and art. 8th of
# Decree No. 9,308, of March 15, 2018;
# III - will be in force until December 31st of each year; and
# IV - will be published on the ANP website (www.anp.gov.br). Section I
# Criteria for Calculating the Individual Annual Goal
# Art. 3rd The calculation of the individual annual target will consider:
# I - fossil fuel movement data reported in the Information System
# of Product Movements - SIMP, under the terms of ANP Resolution No.
#
# Chunk 2:
# 729, of May 11, 2018,
# sent by the ANP to the Federal Audit Court in compliance with art. 1º-A, § 2º, item II, and § 4º, item
# I, of Law No. 10,336, of December 19, 2001. II - the market share of fuel distributors in the marketing of
# fossil fuels that have substitute biofuels on a commercial scale, as per
# detailed in item I of the Annex. 14/10/2025, 13:50
# RESOLUTION Nº 791, OF JUNE 12, 2019 - RESOLUTION Nº 791, OF JUNE 12, 2019 - DOU - Imprensa Nacional
# https://www.in.gov.br/en/web/dou/-/resolucao-n-791-de-12-de-junho-de-2019-163598743
# 1/5
# Art. 4th The ANP will annually publish preliminary targets and the data used for their calculation,
# in the month of December of the year before the definitive annual target comes into effect. Single paragraph. Preliminary goals will use fuel movement data
# fossils reported in SIMP considering the period from January to October of the year prior to the validity of the
# goal. Art. 5th The definitive individual annual target, for each distributor, will be published by March 31st
# of the year of its validity. Single paragraph. The definitive goals will use fuel movement data
# fossils, referred to in section I of art. 3rd, considering the period from January to December of the year prior to the
# duration of the target. Art. 6th The market share of each fuel distributor will be calculated based on
# based on the following variables and formulas:
# I - sum of the volume sold by the distributor in the period relating to each of the
# fuels listed in item I of the Annex;
# II - quantity of fossil fuel corresponding to the volume of each product
# sold, discounting the amount of biofuel in the product;
# III - calculation of greenhouse gas emissions from commercialized fossil fuels
# according to the formula contained in item II of the Annex;
# IV - sum of emissions corresponding to each fossil fuel sold by the
# distributor, according to the formula contained in item III of the Annex; and
# V - distributor's market share, according to the formula contained in item IV of the Annex. § 1 The commercialization of fossil fuel that does not have a national supply of biofuel
# substitute on a commercial scale will not be counted towards the distributor's goal calculation.
# fuels.
#
# Chunk 3:
# § 2 Annually, the ANP will publish, on its website, an updated list with the codes of the
# SIMP corresponding table referring to the products and operations considered for calculating the
# market share in the sale of fossil fuels. § 3º They will be disregarded from the sum of the volume of each fuel sold by the
# distributor those volumes sold to another distributor and volumes intended for
# export. Art. 7º In cases of merger, spin-off and incorporation of fuel distributors, the
# obligations relating to the individual greenhouse gas reduction target will be transferred
# automatically to the successor company. § 1º In the hypotheses provided for in the caput, the ANP must be communicated by interested parties with
# aimed at establishing the company's individual greenhouse gas reduction targets
# successor, without prejudice to the obligations contained in other resolutions. § 2 In the case of a split between fuel distributors, the obligation relating to the individual target
# of greenhouse gas reduction will be joint among the successor companies. CHAPTER II
# PROOF OF COMPLIANCE WITH THE INDIVIDUAL ANNUAL GOAL
# Art. 8 Proof of compliance with the individual annual target for reducing emissions of
# greenhouse gas emissions will be based on information sent by the institutions involved
# in the distribution, intermediation, negotiation and custody activities of Decarbonization Credits
# (CBIO). § 1 Up to fifteen percent of the individual target of one year (t) may be proven by the
# fuel distributor in the subsequent year (t+1), as long as it has fully met the target
# in the previous year(t-1). 14/10/2025, 13:50
# RESOLUTION Nº 791, OF JUNE 12, 2019 - RESOLUTION Nº 791, OF JUNE 12, 2019 - DOU - Imprensa Nacional
# https://www.in.gov.br/en/web/dou/-/resolucao-n-791-de-12-de-junho-de-2019-163598743
# 2/5
# § 2 When the provisions of § 1 occur, the fuel distributor must comply with
# fully meet the target established for the subsequent year (t+1), plus fifteen percent of the target
# individual not proven in the previous year (t). § 3 When there is no individual target established for the previous year (t-1), it will not be possible
# prove in the subsequent year (t+1) no portion of the individual target for a given year (t). Art.
#
# Chunk 4:
# regardless of whether additives are added or not. b) Type C premium gasoline: fuel obtained from a mixture of type A premium gasoline and ethanol
# anhydrous fuel, in the proportions defined by current legislation. All products included
# regardless of whether additives are added or not. c) Diesel oil B: diesel oil for road and non-road use, defined as a mixture of oil
# diesel A and biodiesel at the level established by current legislation. All products included
# regardless of the sulfur content and whether or not additives are added.
#
# Chunk 6:
# d) BX diesel oil: mixture composed of A diesel oil and biodiesel at a different content than
# compulsory established by current legislation. II - Formula for calculating greenhouse gas emissions from fossil fuels
# commercialized
# Emissionsi= ViTotal* pi* ICi* PCIi
# In which:
# Emissionsi: is the amount of greenhouse gas emissions released in the life cycle of the
# fossil fuel i (in tons of CO2equivalent);
# ViTotal: is the total volume sold of fossil fuel i by the fuel distributor
# fuels in the period (in liters);
# pi: is the specific mass of fossil fuel i (in kilograms/liter);
# ICi:
# and
# the
# intensity
# of
# carbon
# of
# fuel
# fossil
# i
# (in
# tons
# of
# CO2equivalent/megajoule);
# PCIi: is the lower calorific value of fossil fuel i (in megajoule/kilogram). The specific mass, carbon intensity and lower calorific value values ​​are those
# defined by ANP Resolution No. 758, of November 23, 2018 or another that replaces it. III - Formula for calculating total emissions per fuel distributor
# Emissionsdistributor= ∑inEmissionsi
# In which:
# Distributor emissions: is the total fossil fuel emissions per distributor
# fuels (in tons of CO2equivalent). i: is each fossil fuel with a national supply of substitute biofuels at scale
# commercial;
# n: is the number of fossil fuels sold by the fuel distributor. IV - Formula for calculating market share in fuel sales
# fossils by fuel distributor
# Distributor participation = (Distributor emissions / ∑k1Distributor emissions) * 100
# In which:
# 14/10/2025, 13:50
# RESOLUTION Nº 791, OF JUNE 12, 2019 - RESOLUTION Nº 791, OF JUNE 12, 2019 - DOU - Imprensa Nacional
# https://www.in.gov.br/en/web/dou/-/resolucao-n-791-de-12-de-junho-de-2019-163598743
# 4/5
# Distributor participation is the percentage of market share in the sale of
# fossil fuels from distributor j (in percentage);
# k: is the total number of fuel distributors that have sold fuel
# fossils. This content does not replace that published in the certified version.
#
# Chunk 7:
# 14/10/2025, 13:50
# RESOLUTION Nº 791, OF JUNE 12, 2019 - RESOLUTION Nº 791, OF JUNE 12, 2019 - DOU - Imprensa Nacional
# https://www.in.gov.br/en/web/dou/-/resolucao-n-791-de-12-de-junho-de-2019-163598743
# 5/5
#
# Chunk 8:
# Published on: 06/05/2020 | Edition: 107-A | Section: 1 - Extra | Page: 1
#
#
# Amends Decree No. 8,874, of October 11, 2016, to provide
# on encouraging the financing of infrastructure projects
# with environmental and social benefits. , in the use of the attribution conferred on it by art. 84, , item IV,
# of the Constitution, and in view of the provisions of art. 2nd of Law No. 12,431, of June 24, 2011,
#  :
# Art. 1st Decree No. 8,874, of October 11, 2016, comes into force with the following
# changes:
# "Art. 2nd .............................................................................................................. I - object of a concession, permission, lease, authorization or public-public partnership process
# private sector, in accordance with the provisions of Law No. 11,079, of December 30, 2004, and which are part of the Program
# of Investment Partnerships of the Presidency of the Republic - PPI, referred to in Law No. 13,334, of 13 December
# September 2016, or the program that succeeds it;
# II - that provide relevant environmental or social benefits; or
# III - not achieved by the provisions of items I and II of the , but approved by the Ministry
# responsible sector and carried out by concessionaire, permittee, authorizer, lessee or
# Specific Purpose Company - SPE.
#
# Chunk 9:
# ..........................................................................................................................
# § 4 For the purposes of the provisions of section II of the , projects that provide
# relevant environmental or social benefits:
# I - in the urban mobility sector, the following non-motorized public transport systems
# and low-carbon public transport:
# a) urban transport systems on rails:
# 1. monorails;
# 2. subways;
# 3. urban trains; and
# 4. Fast Rail Vehicles - VLT;
# b) acquisition of electric buses, including fuel cells, and hybrid buses
# biofuel or biogas, for transport systems; and
# c) implementation of infrastructure;
# II - in the energy sector, projects based on:
# a) renewable technologies for generating solar, wind and waste energy; and
# b) small hydroelectric plants with a minimum power density of 4W/m² (four watts
# per square meter) of flooded area;
# III - in the basic sanitation sector, the following systems:
# a) water supply;
# b) sanitary sewage;
# 10/14/2025, 14:42
# DECREE No. 10,387, OF JUNE 5, 2020 - DECREE No. 10,387, OF JUNE 5, 2020 - DOU - National Press
# https://www.in.gov.br/en/web/dou/-/decreto-n-10.387-de-5-de-junho-de-2020-260391759
# 1/2
# c) rainwater management and urban drainage; and
# d) urban solid waste management; or
# IV - projects carried out in subnormal agglomerations or isolated urban areas, as they are
# considered social benefits, in accordance with the definition established by the Brazilian Institute of
# Geography and Statistics - IBGE. § 5 The provisions of item IV of § 4 apply to projects that fall within one of the sectors
# referred to in § 1.
#
# Chunk 10:
# § 6 For the purposes of the provisions of item III of § 4, the proposed interventions must be
# contemplated in the concession contract or program contract." (NR)
# "Art. 3rd ..............................................................................................................
# ...........................................................................................................................................
# § 5º The ordinance referred to in § 4º, when dealing with the projects referred to in section II
# of art. 2nd, you must:
# I - establish simplified requirements for approval, through requirements verification
# institutions of the project holder and the legal entity responsible for implementing the project, if
# are not coincident; and
# II - establish a way to monitor project stages based on data
# self-declared by the project owner and in the reports he periodically sends to
# Responsible sectoral ministries." (NR)
# Art. 2 This Decree comes into force on the date of its publication. Brasília, June 5, 2020; 199th of Independence and 132nd of the Republic. Paulo Guedes
# This content does not replace that published in the certified version. 10/14/2025, 14:42
# DECREE No. 10,387, OF JUNE 5, 2020 - DECREE No.

# %%
def call_llm(line):
    this_prompt = get_user_prompt(line)
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": this_prompt}])
    return response

# %%
results = []

# %%
# Make sure results_df exists before the loop (it is created after this, so initialize it with prior results if file exists)
import os

if os.path.exists("responses_df.csv"):
    results_df = pd.read_csv("responses_df.csv")
else:
    results_df = pd.DataFrame(columns=['file', 'country', 'chunk_text', 'response'])

total_chunks = len(chunked_df)
for i in range(total_chunks):
    this_chunk = chunked_df['chunk_text'].iloc[i]
    this_file = chunked_df['file'].iloc[i]
    this_country = chunked_df['country'].iloc[i]

    # Only proceed if this chunk/file/country is not already in results_df
    mask = (
        (results_df['file'] == this_file) &
        (results_df['country'] == this_country) &
        (results_df['chunk_text'] == this_chunk)
    )
    if mask.any():
        continue  # Skip if found

    print(f"Processing chunk {i+1} of {total_chunks} (remaining: {total_chunks - i - 1})")
    this_response = call_llm(this_chunk)
    this_response_slim = this_response.choices[0].message.content
    print(this_response_slim)
    results.append({
        'file': this_file,
        'country': this_country,
        'chunk_text': this_chunk,
        'response': this_response_slim
    })
    pd.DataFrame(results).to_csv("responses_df.csv", index=False)
    results_df = pd.DataFrame(results)
# Out:
# Processing chunk 1 of 9302 (remaining: 9301)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk

# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9263 of 9302 (remaining: 39)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9264 of 9302 (remaining: 38)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9265 of 9302 (remaining: 37)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9266 of 9302 (remaining: 36)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9267 of 9302 (remaining: 35)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9268 of 9302 (remaining: 34)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9269 of 9302 (remaining: 33)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9270 of 9302 (remaining: 32)
# {
#   "has_policy_instruments": true,
#   "policy_instruments": ["Directive 2003/87/EC", "Council Directive 2003/96/EC"]
# }
# Processing chunk 9271 of 9302 (remaining: 31)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9272 of 9302 (remaining: 30)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9273 of 9302 (remaining: 29)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9274 of 9302 (remaining: 28)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9275 of 9302 (remaining: 27)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9276 of 9302 (remaining: 26)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9277 of 9302 (remaining: 25)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9278 of 9302 (remaining: 24)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9279 of 9302 (remaining: 23)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9280 of 9302 (remaining: 22)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9281 of 9302 (remaining: 21)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9282 of 9302 (remaining: 20)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9283 of 9302 (remaining: 19)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9284 of 9302 (remaining: 18)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9285 of 9302 (remaining: 17)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9286 of 9302 (remaining: 16)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9287 of 9302 (remaining: 15)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9288 of 9302 (remaining: 14)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9289 of 9302 (remaining: 13)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9290 of 9302 (remaining: 12)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9291 of 9302 (remaining: 11)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9292 of 9302 (remaining: 10)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9293 of 9302 (remaining: 9)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9294 of 9302 (remaining: 8)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9295 of 9302 (remaining: 7)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9296 of 9302 (remaining: 6)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9297 of 9302 (remaining: 5)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9298 of 9302 (remaining: 4)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9299 of 9302 (remaining: 3)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9300 of 9302 (remaining: 2)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9301 of 9302 (remaining: 1)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }
# Processing chunk 9302 of 9302 (remaining: 0)
# {
#   "has_policy_instruments": false,
#   "policy_instruments": []
# }

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#         file country                                         chunk_text  \
# 0     61.pdf  Brazil  .................................................
# 1     61.pdf  Brazil  § 6 For the purposes of the provisions of item...
# 2     61.pdf  Brazil  10,387, OF JUNE 5, 2020 - DOU - National Press...
# 3     75.pdf  Brazil  Presidency of the Republic \nCivil House \nDep...
# 4     75.pdf  Brazil  32 The application of FNMC resources may be al...
# ...      ...     ...                                                ...
# 9297  44.pdf      EU  131).’\n(5) Annex IIIb to Directive 1999/62/EC...
# 9298  44.pdf      EU  If there is \nscientific evidence for a higher...
# 9299  44.pdf      EU  The parts of the network subject to congestion...
# 9300  44.pdf      EU  The resulting \ncharging structure shall be tr...
# 9301  44.pdf      EU  Congestion charge for \nother vehicle categori...
#
#                                                response
# 0     {\n  "has_policy_instruments": false,\n  "poli...
# 1     {\n  "has_policy_instruments": false,\n  "poli...
# 2     {\n  "has_policy_instruments": false,\n  "poli...
# 3     {\n  "has_policy_instruments": true,\n  "polic...
# 4     {\n  "has_policy_instruments": true,\n  "polic...
# ...                                                 ...
# 9297  {\n  "has_policy_instruments": false,\n  "poli...
# 9298  {\n  "has_policy_instruments": false,\n  "poli...
# 9299  {\n  "has_policy_instruments": false,\n  "poli...
# 9300  {\n  "has_policy_instruments": false,\n  "poli...
# 9301  {\n  "has_policy_instruments": false,\n  "poli...
#
# [9302 rows x 4 columns]

# %%
results_df.iloc[0].response
# Out:
# '{\n  "has_policy_instruments": false,\n  "policy_instruments": []\n}'

# %%
# extract true/false (has_policy_instruments) from response for each row

import json

def extract_true_false(response_str):
    try:
        response_json = json.loads(response_str)
        return response_json.get("has_policy_instruments")
    except Exception:
        return None

# Add a new column to results_df with the extracted true/false values
results_df['has_policy_instruments'] = results_df['response'].apply(extract_true_false)
results_df.head()
# Out:
#      file country                                         chunk_text  \
# 0  61.pdf  Brazil  .................................................
# 1  61.pdf  Brazil  § 6 For the purposes of the provisions of item...
# 2  61.pdf  Brazil  10,387, OF JUNE 5, 2020 - DOU - National Press...
# 3  75.pdf  Brazil  Presidency of the Republic \nCivil House \nDep...
# 4  75.pdf  Brazil  32 The application of FNMC resources may be al...
#
#                                             response has_policy_instruments
# 0  {\n  "has_policy_instruments": false,\n  "poli...                  False
# 1  {\n  "has_policy_instruments": false,\n  "poli...                  False
# 2  {\n  "has_policy_instruments": false,\n  "poli...                  False
# 3  {\n  "has_policy_instruments": true,\n  "polic...                   True
# 4  {\n  "has_policy_instruments": true,\n  "polic...                   True

# %%
true_df = results_df[results_df['has_policy_instruments'] == True]

# %%
true_df.iloc[0].response
# Out:
# '{\n  "has_policy_instruments": true,\n  "policy_instruments": ["National Fund on Climate Change - FNMC"]\n}'

# %%
# Extract a comma-separated string of policy instruments from the 'response' column in true_df, removing brackets

def extract_policy_instruments_str(response_str):
    try:
        response_json = json.loads(response_str)
        instr_list = response_json.get("policy_instruments", [])
        # Join list into comma-separated string, or return empty string if not a list
        if isinstance(instr_list, list):
            return ', '.join(str(instr) for instr in instr_list)
        else:
            return str(instr_list)
    except Exception:
        return None

# Add a new column 'policy_instruments' (as string) to true_df
true_df['policy_instruments'] = true_df['response'].apply(extract_policy_instruments_str)

# Display the first few rows with policy instrument strings
true_df
# Out:
# /var/folders/br/4mkn2pts7yg8xb1_dfd6g01c0000gn/T/ipykernel_5540/3581868005.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   true_df['policy_instruments'] = true_df['response'].apply(extract_policy_instruments_str)
#         file country                                         chunk_text  \
# 3     75.pdf  Brazil  Presidency of the Republic \nCivil House \nDep...
# 4     75.pdf  Brazil  32 The application of FNMC resources may be al...
# 5     75.pdf  Brazil  ß 12 0 annual application plan must include: \...
# 6     75.pdf  Brazil  12,114, of 2009; \n \n \n      II - approve th...
# 11    74.pdf  Brazil  2nd The National Crop-Livestock-Forest Integra...
# ...      ...     ...                                                ...
# 9221   2.pdf      EU  Amounts that would be due to be paid by the Co...
# 9222   2.pdf      EU  Where the amount of \na contribution agreement...
# 9225   2.pdf      EU  However, in order to effectively \nsupport non...
# 9226   2.pdf      EU  \neuropa.eu/eli/reg/2024/795/oj).’.\nArticle 1...
# 9269  44.pdf      EU  Where Member States apply this paragraph they ...
#
#                                                response  \
# 3     {\n  "has_policy_instruments": true,\n  "polic...
# 4     {\n  "has_policy_instruments": true,\n  "polic...
# 5     {\n  "has_policy_instruments": true,\n  "polic...
# 6     {\n  "has_policy_instruments": true,\n  "polic...
# 11    {\n  "has_policy_instruments": true,\n  "polic...
# ...                                                 ...
# 9221  {\n  "has_policy_instruments": true,\n  "polic...
# 9222  {\n  "has_policy_instruments": true,\n  "polic...
# 9225  {\n  "has_policy_instruments": true,\n  "polic...
# 9226  {\n  "has_policy_instruments": true,\n  "polic...
# 9269  {\n  "has_policy_instruments": true,\n  "polic...
#
#      has_policy_instruments                                 policy_instruments
# 3                      True             National Fund on Climate Change - FNMC
# 4                      True                                               FNMC
# 5                      True                            Law No. 12,114, of 2009
# 6                      True                                               FNMC
# 11                     True  National Crop-Livestock-Forest Integration Policy
# ...                     ...                                                ...
# 9221                   True                           Regulation (EU) 2024/795
# 9222                   True                          Regulation (EU) 2021/1060
# 9225                   True  Regulation (EU) 2024/795, Regulation (EU) 2021...
# 9226                   True  Regulation (EU) 2021/241, Regulation (EU) 2021...
# 9269                   True  Directive 2003/87/EC, Council Directive 2003/9...
#
# [973 rows x 6 columns]

# %%
true_df.policy_instruments.iloc[15]
# Out:
# 'PROCEL, PBE'

# %%
import re
import pandas as pd

def split_policy_instruments(instr_str):
    # Split only on commas followed by a space and then a capital letter
    # This identifies the start of a new policy name
    # Example: "National Plan of Energy 2030, National Energy Matrix 2030"
    # Will split into: ["National Plan of Energy 2030", "National Energy Matrix 2030"]
    # But won't split: "Regulation (EU) 2021, 1060" (no capital after comma+space)
    if not isinstance(instr_str, str) or not instr_str.strip():
        return []
    pattern = r',\s+(?=[A-Z])'
    items = [item.strip() for item in re.split(pattern, instr_str) if item.strip()]
    return items

# Build a list of dicts: each with file, country, policy_instrument
rows = []
for idx, row in true_df.iterrows():
    file = row['file']
    country = row['country']
    policy_str = row['policy_instruments']
    policy_list = split_policy_instruments(policy_str)
    for pol in policy_list:
        if pol.strip():  # skip empty
            rows.append({
                "file": file,
                "country": country,
                "policy_instrument": pol.strip()
            })

policy_instruments_df = pd.DataFrame(rows)
policy_instruments_df  # this df has columns: file, country, policy_instrument
# Out:
#         file country                                  policy_instrument
# 0     75.pdf  Brazil             National Fund on Climate Change - FNMC
# 1     75.pdf  Brazil                                               FNMC
# 2     75.pdf  Brazil                            Law No. 12,114, of 2009
# 3     75.pdf  Brazil                                               FNMC
# 4     74.pdf  Brazil  National Crop-Livestock-Forest Integration Policy
# ...      ...     ...                                                ...
# 1877   2.pdf      EU                           Regulation (EU) 2021/241
# 1878   2.pdf      EU                           Regulation (EU) 2021/523
# 1879   2.pdf      EU                           Regulation (EU) 2024/795
# 1880  44.pdf      EU                               Directive 2003/87/EC
# 1881  44.pdf      EU                       Council Directive 2003/96/EC
#
# [1882 rows x 3 columns]

# %%
b_df_policies = policy_instruments_df[policy_instruments_df['country'] == 'Brazil']
eu_df_policies = policy_instruments_df[policy_instruments_df['country'] == 'EU']
c_df_policies = policy_instruments_df[policy_instruments_df['country'] == 'China']

# %%
b_df_policies
# Out:
#        file country                                  policy_instrument
# 0    75.pdf  Brazil             National Fund on Climate Change - FNMC
# 1    75.pdf  Brazil                                               FNMC
# 2    75.pdf  Brazil                            Law No. 12,114, of 2009
# 3    75.pdf  Brazil                                               FNMC
# 4    74.pdf  Brazil  National Crop-Livestock-Forest Integration Policy
# ..      ...     ...                                                ...
# 698  45.pdf  Brazil                                  National ABC Plan
# 699  45.pdf  Brazil                                       Climate Fund
# 700  45.pdf  Brazil                                        Amazon Fund
# 701  50.pdf  Brazil                                        ABC Program
# 702  50.pdf  Brazil  Programa para Redução da Emissão de Gases de E...
#
# [703 rows x 3 columns]

# %%
c_df_policies
# Out:
#        file country                                  policy_instrument
# 703  49.pdf   China                              Carbon Trading System
# 704  49.pdf   China               Carbon Emission Certification System
# 705  49.pdf   China                                             Fiscal
# 706  49.pdf   China                      Taxation and Pricing Policies
# 707  49.pdf   China                  Investment and Financing Policies
# ..      ...     ...                                                ...
# 817  40.pdf   China             Climate investment and financing pilot
# 818  46.pdf   China  Measures for the Management of Central Budgeta...
# 819  45.pdf   China     green finance, green development policy system
# 820   2.pdf   China  financial service support, credit management a...
# 821  50.pdf   China  Green tax system, incentive policies to promot...
#
# [119 rows x 3 columns]

# %%
eu_df_policies
# Out:
#         file country             policy_instrument
# 822   49.pdf      EU          European Climate Law
# 823   49.pdf      EU     Carbon Farming Initiative
# 824   49.pdf      EU    Common Agricultural Policy
# 825   49.pdf      EU            InvestEU Programme
# 826   49.pdf      EU                   EU taxonomy
# ...      ...     ...                           ...
# 1877   2.pdf      EU      Regulation (EU) 2021/241
# 1878   2.pdf      EU      Regulation (EU) 2021/523
# 1879   2.pdf      EU      Regulation (EU) 2024/795
# 1880  44.pdf      EU          Directive 2003/87/EC
# 1881  44.pdf      EU  Council Directive 2003/96/EC
#
# [1060 rows x 3 columns]

# %%
import difflib

def mark_first_instance(df, policy_col='policy_instrument', threshold=0.8):
    """
    Adds a column 'first_instance' to the DataFrame, which is 1 for the first (canonical) occurrence 
    of a fuzzy-unique policy, and 0 for subsequent fuzzy duplicates.
    Args:
        df: DataFrame with a column of policy strings (policy_col)
        policy_col: string, name of policy column
        threshold: float (0-1), similarity ratio above which two entries are considered the same
    Returns:
        DataFrame with additional 'first_instance' column (1/0)
    """
    # Keep track of seen policies (canonical representatives)
    unique_policies = []
    first_instance_list = []
    for pol in df[policy_col]:
        pol_clean = pol.strip().lower()
        found = False
        for i, existing in enumerate(unique_policies):
            existing_clean = existing.strip().lower()
            # quick exact containment or equality
            if pol_clean == existing_clean or pol_clean in existing_clean or existing_clean in pol_clean:
                found = True
                # Prefer the longer string as more descriptive
                if len(pol) > len(existing):
                    unique_policies[i] = pol
                break
            # fuzzy
            ratio = difflib.SequenceMatcher(None, pol_clean, existing_clean).ratio()
            if ratio >= threshold:
                found = True
                # Prefer the longer string as more descriptive
                if len(pol) > len(existing):
                    unique_policies[i] = pol
                break
        if not found:
            unique_policies.append(pol)
            first_instance_list.append(1)  # First unique occurrence
        else:
            first_instance_list.append(0)  # Duplicate (fuzzy)
    df = df.copy()
    df['first_instance'] = first_instance_list
    return df

# %%
b_df_policies = mark_first_instance(b_df_policies)
b_df_policies.head()
# Out:
#      file country                                  policy_instrument  \
# 0  75.pdf  Brazil             National Fund on Climate Change - FNMC
# 1  75.pdf  Brazil                                               FNMC
# 2  75.pdf  Brazil                            Law No. 12,114, of 2009
# 3  75.pdf  Brazil                                               FNMC
# 4  74.pdf  Brazil  National Crop-Livestock-Forest Integration Policy
#
#    first_instance
# 0               1
# 1               0
# 2               1
# 3               0
# 4               1

# %%
# The previous code attempts to use .iloc with a string, which is incorrect.
# To select all rows for file '44.pdf', use boolean indexing:
b_df_policies[b_df_policies['file'] == '44.pdf']
# Out:
# Empty DataFrame
# Columns: [file, country, policy_instrument, first_instance]
# Index: []

# %%
b_df_policies.first_instance.value_counts()
# Out:
# first_instance
# 0    449
# 1    254
# Name: count, dtype: int64

# %% [markdown]
# This means there are 254 policy instruments in Brazil. Let's see what they are

# %%
#print a list of the 254 policy instruments identified in Brazil, where the first_instance is 1
b_policy_list = b_df_policies[b_df_policies['first_instance'] == 1]['policy_instrument'].tolist()
len(b_policy_list)
b_policy_list
# Out:
# ['National Fund on Climate Change - FNMC',
#  'Law No. 12,114, of 2009',
#  'National Crop-Livestock-Forest Integration Policy',
#  'Decree No. 8,874',
#  'Law No. 12,431',
#  'Law No. 13,334',
#  'PNRS instruments',
#  'Decarbonization Credit',
#  'National Plan of Energy 2030 - PNE 2030',
#  'National Energy Matrix 2030 - MEN 2030',
#  'PROINFA',
#  'Brazilian Labeling Law',
#  'Energy Efficiency Law',
#  'National Biodiesel Program',
#  'National Alcohol Program – PROALCOOL',
#  'Law No. 11,241, of September 19, 2002',
#  'PROCEL',
#  'PBE',
#  'National Rationalization Program - CONPET',
#  'Law of Energy Efficiency (nº 10,295/01)',
#  'Law nº 9,991/00',
#  'CONPET Seal',
#  'National Energy Efficiency Policy',
#  'CIMGC Resolution No. 9 of 03/20/2009',
#  'Program of Activities (PoA)',
#  'Clean Development Mechanism (CDM)',
#  'Action Plan for Prevention and Control of Deforestation and Fires in the Cerrado (PPCerrado)',
#  'Programa Agricultura de Baixo Carbono',
#  'Estratégia Nacional para REDD+',
#  'Política Nacional sobre Mudança do Clima',
#  'Action Plan for the Prevention and Control of Deforestation in the Legal Amazon',
#  'National Policy on Climate Change',
#  'National Strategy for Reducing Greenhouse Gas Emissions from Deforestation and Forest Degradation',
#  'FIP-Cerrado',
#  'Amazon Fund',
#  "Brazil's National Strategy for REDD+",
#  'PPCDAm',
#  'ENREDD+',
#  'Low Carbon Agriculture Plan – ABC',
#  'Community and Family Forest Management Program – PMFC',
#  'National Policy for Environmental and Territorial Management in Indigenous Lands – PNGATI',
#  'Terra Legal Program',
#  'Environmental Conservation Support Program – Bolsa Verde',
#  'Minimum Price Guarantee Policy for Sociobiodiversity Products – PGPM-Bio',
#  'Amazon Protected Areas Program – Arpa',
#  'Soy Moratorium',
#  'National Integrated Fire Management Policy',
#  'Law nº 12,187/2009)',
#  'Action Plans for Preventing and Controlling Deforestation',
#  'Program for Prevention',
#  'Combat and Alternatives to Illegal Deforestation in Settlements of the Amazon',
#  'Municipal Pact to Reduce Deforestation',
#  'Decree nº 6321/2007',
#  'Ordinance no. 361, of September 8, 2017',
#  'ABC Program',
#  'Pronaf',
#  'MCR',
#  'BNDES, green bonds',
#  'CMN/Bacen Resolution No. 3,545/2008',
#  'Resolution CMN/Bacen nº 4327',
#  'Environmental Reserve Quota (CRA)',
#  'Interministerial Commission for Global Climate Change',
#  'Low Carbon Agriculture Program',
#  'PPG7',
#  'Public Forest Management Law (Law No. 11,284/2006)',
#  'National Policy on Changing the Climate (PNMC)',
#  'National Climate Change Fund',
#  'Decree No. 7,343/2010',
#  'Climate Fund Program',
#  'National REDD+ Strategy',
#  'Green Settlements Program',
#  'Legal Amazon MacroZEE',
#  'National Conservation Units (Law nº 9,985/2000)',
#  'Pro-recovery',
#  'Operation Arco Verde',
#  'PRONAF Floresta',
#  'PRONAF Eco',
#  'PRONAF Agroecologia',
#  'PRONAF Agroindústria',
#  'FNO Amazônia Rural Sustentável',
#  'FNO Biodiversity',
#  'FNO-Amazônia Sustentável Program',
#  'FNO-Biodiversity Program',
#  'Community Sustainable Forest Management Plans (Community PMFS)',
#  'Programa Áreas Protegidas da Amazônia',
#  'Forest Investment Program',
#  'Plano de Ação para Prevenção e Controle do Desmatamento na Amazônia Legal',
#  'Sistema Nacional de Cadastro Ambiental Rural',
#  'Conservation of Forest Carbon Stocks',
#  'Management Sustainable Forestry and Increased Forest Carbon Stocks',
#  'Cerrado-Jalapão Project',
#  'Cerrado Program',
#  'Public Call for Sustainable Productive Projects',
#  'Public Call for Support for Preparation and Implementation of Territorial and Environmental Management plans (PGTA) in Indigenous Lands of the Amazon biome',
#  'Deforestation Prevention and Control plans',
#  'Law No. 12,651/2012',
#  'Forest Emissions Reference Level',
#  'Warsaw Framework for REDD+',
#  'National Energy Plan 2050',
#  'PLANO NACIONAL DE ENERGIA 2050',
#  'Law 13,280/2,016',
#  'Renewable Energy Certificates',
#  'Pricing of Carbon',
#  'Law 12,187 of 2009',
#  'National Biofuels Policy – RenovaBio',
#  'Law No. 13,576, of December 26, 2017',
#  'Nationally Determined Contribution',
#  'National Efficiency Plan',
#  'National Contribution Determined – NDC, green bond markets',
#  'Alternative Sources Incentive Program of Electric Energy (PROINFA)',
#  'Ten-Year Energy Efficiency Plan',
#  'Rota2030',
#  'Proconve',
#  'State Mineral Coal Policy',
#  'National Program for Rationalization of the Use of Petroleum and Natural Gas Derivatives (CONPET)',
#  'Normative Resolution (REN) No. 482/2012',
#  'Law No. 13,576/2017',
#  'Transport and Urban Mobility Sector Plan for Mitigation and Adaptation to Climate Change (PSTM)',
#  'National Payments for Environmental Services - Floresta+',
#  'Floresta+ Program',
#  'National Green Growth Program',
#  'PDE 2031',
#  'Law no. 14,182/2021',
#  'Law 14,134',
#  'Decree 10,712',
#  'Future Fuel Program',
#  'National Forest Development Fund - FNDF',
#  'Law No. 14,590 of 2023',
#  'Provisional Measure No. 1,151 of 2022',
#  'Fair Energy Transition Program (TEJ)',
#  'National Commission for REDD+',
#  'Brazilian Emissions Reduction Market',
#  'Brazilian Green Gas Emissions Trading System',
#  'fiscal and tax measures designed to encourage the reduction of emissions and removal of greenhouse gases, specific credit and financing lines from public and private financial agents, financial and economic mechanisms relating to climate change mitigation and adaptation, existing measures that stimulate the development of processes and technologies that contribute to the reduction of emissions and removal of greenhouse gases',
#  'Green Climate Fund',
#  'Decree No. 11,367, of January 1, 2023',
#  'Environmental Servant (CRA), payment programs for environmental services (PSA)',
#  'Flores-ta+',
#  'Bolsa Verde Program',
#  'REDD+ pilot project for Amazon',
#  'Law No. 11,284, of March 2, 2006',
#  'Law No. 11,132, of July 4, 2005',
#  'Strategic Plan of the Interstate Consortium 2019-2030',
#  'Plan of Green Recovery (PRV)',
#  'Manaus Action Plan',
#  'Law No. 11,952, of June 25, 2009',
#  'Federal Decree nº 6321 of December 21, 2007',
#  'Term of Legal Meat Conduct Adjustment (TAC)',
#  'Green Grains Protocol',
#  'National Policy for Territorial and Environmental Management of Indigenous Lands (PNGATI)',
#  'Law No. 14,119, of January 13, 2021',
#  'National Benefit Sharing Fund (FNRB)',
#  'National Environment Fund (FNMA)',
#  'Fund for the Defense of Diffuse Rights (FDD)',
#  'National Fund for Scientific and Technological Development (FNDCT)',
#  'Fund of the Constitutional Financing of the North (FNO)',
#  'Decreto nº 11.367, de 1º de janeiro de 2023',
#  'Quality Assurance Policy Minimum Prices for Sociobiodiversity Products (PGPM-Bio)',
#  'More Sustainable Amazon Program',
#  'Green Recovery Plan (PRV)',
#  "National Treasury's sustainable bond issuance strategy",
#  'National Program for Strengthening Family Agriculture (Pronaf)',
#  'Floresta+ project',
#  'Rural Production Certificate Green',
#  'Brazilian Market for Emissions Reduction',
#  'Green Taxonomy proposal',
#  'Selo Amazônia',
#  'Selo Verde',
#  'Marca Amazônia',
#  'Programa Nacional de Bioeconomia para a Sociobiodiversidade',
#  'Program More Sustainable Amazon',
#  'Green Taxonomy of activities',
#  'Market Brazilian from reduction of emissions (MBRE)',
#  'MDR',
#  'Amazon Fund, green bonds',
#  'Produtor de Águas',
#  'Decree No. 11,368 of 2023',
#  'MODERFROTA',
#  'MODERAGRO',
#  'INOVAGRO',
#  'Multi-Year Plan (PPA)',
#  'State Prevention and Control of Deforestation and Fires (PPCDQ)',
#  'State Prevention Plan and Deforestation Control',
#  'Prevention and Control Plan Deforestation Trolley',
#  'Burns and Fires Forestry of the State of Amapá',
#  'State Prevention Plan tion and Combating Weaning tation of Amazonas',
#  'Action Plan for Prevention and control of Deforestation and Burns made in the State of Maranhão',
#  'Action Plan for prevention and control of killing and fires Forestry of the State of Mato Grosso',
#  'Amazon State Plan Now',
#  'Control and promotion of sustainable alternatives to deforestation and burning from Rondônia',
#  'State Prevention Plan tion and Weaning Control cultivation and fires Roraima',
#  'Prevention Plan and Combating Deforestation ments and Flores such as Tocantins',
#  'Food Acquisition Program (PAA)',
#  'National Food Program School (PNAE)',
#  'Payment of Services Environmental (PSA)',
#  'Law 14.300',
#  'Programa Nacional de Conservação de Energia Elétrica',
#  'Plano Nacional de Eficiência Energética',
#  'National Energy Conservation Program Electricity (PROCEL)',
#  'Law No. 9,991',
#  'Global Reversion Reserve (RGR)',
#  'CT-ENERG',
#  'PROESCO',
#  'BNDES FINAME',
#  'PROCEL program Industry',
#  'Energy Efficiency – PEE',
#  'Energy Independence and Security Act of 2007',
#  'Program National Council for Production and Use of Biodiesel',
#  'Law no. 10,295/2001',
#  'Efficiency Law Energy',
#  'Energy Efficiency Accreditation Scheme',
#  'Energy Performance Certificate Program of Buildings',
#  'Energy Services Performance Contracts',
#  'Ordinance 113-MME',
#  'Normative Instruction No. 01',
#  'Law 12,212',
#  'Resolution 492/2002-ANEEL',
#  'Financing lines for energy efficiency sector',
#  'Promotion of energy efficiency as a criterion for obtaining credit from public financing entities',
#  'Expansion of financing lines for the sanitation sector specific to energy efficiency',
#  'Law No. 3,486 of June 19, 2001',
#  'Law nº 4,507, of March 30, 2005',
#  'Complementary Law No. 560, of January 3, 2007',
#  'Decree nº 49,148, of January 21, 2008',
#  'Law nº 1,045 of August 2, 2006',
#  'Residential Leasing Program (PAR)',
#  'Minha Casa',
#  'Minha Vida Program (PMCMV)',
#  'Law changing the use of FGTS for the implementation of thermosolar systems, financing lines for the acquisition of thermosolar systems',
#  'PROCEL Seal Program',
#  'Memorandum of understanding between the Government of the Federative Republic of Brazil and the Government of the Kingdom of Denmark on cooperation in the area of climate change and the development and execution of projects within the scope of clean development mechanism of the Kyoto Protocol',
#  'Memorandum of Understanding on Cooperation in the Area of \u200b\u200bChange Climate and Development and Execution of Projects within the Scope of the Mechanism of Clean Development of the Kyoto Protocol',
#  'Agreement on Financial Cooperation for the Project “Programa de Renewable Energy Credit”',
#  'Inova Brazil',
#  'Law 10,973/04',
#  'Decree 5,563/05',
#  'Law 11,196/05',
#  'Decree no. 5,798/06',
#  'Social Renewable Energy Program',
#  'Health Sector Plan for Mitigation and Adaptation to Climate Change',
#  'NATIONAL PLAN FOR CONTROL OF ILLEGAL DEFORESTATION AND RECOVERY OF NATIVE VEGETATION',
#  'Bonds Los Verdes',
#  'Funding Quotas',
#  'Investment in Credit Rights (FIDC)',
#  'Certificate of Receivables from Agribusiness (CRA)',
#  'Real Estate Receivables Certificate (CRI)',
#  'National System of Nature Conservation Units',
#  'Water Producer Program',
#  'Tropical Forest Standard',
#  'National Plan for the Recovery of Native Vegetation',
#  'CENABC',
#  'ABC Plan',
#  'National ABC Plan',
#  'Programa para Redução da Emissão de Gases de Efeito Estufa na Agricultura']

# %%
def get_policy_list(df, country):
    df = mark_first_instance(df)
    policy_list = df[df['first_instance'] == 1]['policy_instrument'].tolist()
    return policy_list

b_policy_list = get_policy_list(b_df_policies, 'Brazil')
c_policy_list = get_policy_list(c_df_policies, 'China')
eu_policy_list = get_policy_list(eu_df_policies, 'EU')

# %%
c_policy_list
# Out:
# ['Carbon Trading System',
#  'Carbon Emission Certification System',
#  'Fiscal',
#  'Taxation and Pricing Policies',
#  'Investment and Financing Policies',
#  "China's National Climate Change Plan",
#  'Twelfth Five-Year Plan for Controlling Greenhouse Gas Emissions',
#  'National Climate Adaptation Plan',
#  'Climate Change Strategy',
#  'low-carbon provincial pilot projects, low-carbon development plans',
#  'Greenhouse Gas Voluntary Emissions Reduction Trading Management Office Law, national carbon emissions trading market, carbon emissions trading pilot',
#  'Low Carbon Product Certification System',
#  'Mandatory Government Green and Low-Carbon Procurement Policies',
#  'carbon emission access thresholds for key industries, green credit institutions system, carbon finance development model, policy investment and financing institutions for low-carbon development',
#  'national carbon emissions trading market, carbon emissions trading management measures, carbon emissions trading certification system',
#  'Low carbon product certification, government green and low-carbon procurement policies',
#  'China Clean Development Mechanism Fund',
#  'South-South Cooperation Fund',
#  'Opinions on Doing a Good Job in Carbon Neutrality to Peak Carbon',
#  'Action Plan for Carbon Peaking Before 2030',
#  'Guofa [2021] No. 23',
#  'carbon emissions trading market, pollution discharge permit system, carbon emission reporting and information disclosure systems for enterprises, financial institutions',
#  'National Low-Carbon Transition Fund',
#  'National Green Development Fund',
#  'National Carbon Emissions Trading Market Construction Plan',
#  'national carbon emissions trading system',
#  'Carbon emission monitoring, reporting and verification system',
#  'Quota management system for key emission units',
#  'Market transaction-related systems',
#  'Quota Management in the Power Generation Industry',
#  'Carbon emission rights registration system',
#  'green credit initiative, green bonds',
#  'Action Plan for Carbon Dioxide Peaking',
#  'instruments for supporting the reduction of carbon emissions',
#  'Guidelines for Fully and Faithfully Implementing the New Development Philosophy in the Work on Achieving Peak Carbon and Carbon Neutrality',
#  'Action Plan for Reaching Peak Carbon Dioxide Emissions before 2030, national carbon emissions trading market',
#  '14th Five-Year Plan for Clean Production',
#  'carbon emissions statistical accounting system, national market for trading carbon emission rights',
#  'Three Star System',
#  'Strategy for Adapting to Climate Change',
#  "The Fourteenth Five-Year Plan for National Economic and Social Development of the People's Republic of China",
#  'Opinions on the Fight against Climate Change',
#  'National Climate Change Plan (2014-2020)',
#  'Opinions on fully implementing the new development concept and doing a good job in peaking carbon neutrality, 2030 Action Plan for Carbon Peaking',
#  'National Climate Change Adaptation Strategy 2035',
#  'Mandatory climate and environmental information disclosure system',
#  'green capital investment, sustainable development-linked bonds, catastrophe insurance, climate risk insurance',
#  'carbon emission reduction support tools, sustainable development-linked bonds, catastrophe insurance, climate risk insurance',
#  'Energy Storage Development Fund',
#  'financial support for carbon peak and carbon neutrality',
#  'One Belt',
#  'One Road Green Investment Principles',
#  'Action Plan for Carbon Peaking before 2030, green finance evaluation mechanism, green finance standard system, national low-carbon transformation fund',
#  'green bond market, national low-carbon transformation fund, green and low-carbon industry investment funds, carbon emissions trading market, energy use rights trading market',
#  'Action Plan for Carbon Peaking before 2030, national low-carbon transformation fund',
#  "China's National Plan to Address Climate Change",
#  'catastrophe bonds, meteorological index insurance',
#  'climate financial markets, catastrophe bonds',
#  'Belt and Road South-South Cooperation Initiative on Climate Change',
#  'Belt and Road Science',
#  'Technology, and Innovation Cooperation Action Plan',
#  'green pricing policy, green finance standard system, green credit, green bond market, national fund for low-carbon transformation',
#  'Regulations on the Disclosure of Corporate Environmental Information in Accordance with the Law',
#  'Measures for the Administration of Legal Disclosure of Corporate Environmental Information',
#  'Guiding Opinions on Promoting Investment and Financing to Address Climate Change',
#  'carbon finance, carbon financial products, corporate carbon accounting systems, climate information disclosure system, green financial products and services',
#  'Regional Climate Investment and Financing Pilot Work Plan',
#  'Climate investment and financing pilot localities',
#  'Measures for the Management of Central Budgetary Investments in Pollution Control and Energy Conservation and Carbon Reduction',
#  'green finance, green development policy system',
#  'financial service support, credit management and loan review systems, intellectual property pledge financing, industrial chain financing, energy-saving and new energy vehicle innovation centers, new energy automobile finance and credit, insurance, leasing, power battery recycling',
#  'Green tax system, incentive policies to promote the development of green credit']

# %%
eu_policy_list
# Out:
# ['European Climate Law',
#  'Carbon Farming Initiative',
#  'Common Agricultural Policy',
#  'InvestEU Programme',
#  'EU taxonomy',
#  'Regulation (EU) 2018/1999 on the Governance of the Energy Union and Climate Action',
#  'Directive 2003/87/EC',
#  'Regulation (EU) 2018/842',
#  'Regulation (EU) 2021/1119',
#  'Just Transition Mechanism',
#  'Just Transition Fund',
#  'Council Regulation (EU',
#  'Euratom) 2020/2093',
#  'Euratom) 2018/1046',
#  'European Investment Bank Facility',
#  'Territorial Just Transition Plan',
#  'InvestEU Advisory Hub',
#  'Union support under the Facility',
#  'Private Finance for Energy Efficiency (PF4EE)',
#  'Natural Capital Financing Facility (NCFF)',
#  'Regulation (EC) No 680/2007',
#  'Commission Decision of 25.2.2010 on European Union participation in the 2020 European Fund for Energy',
#  'Climate Change and Infrastructure',
#  'European Energy Efficiency Fund (EEEF): Regulation (EU) No 1233/2010',
#  'Union Emissions Trading System',
#  'EU Strategy on adaptation to climate change',
#  'European Semester',
#  'Innovative Financial Instruments',
#  'Union Multiannual Financial Framework',
#  'LIFE programme',
#  'European Investment Bank capital increase',
#  'Action plan on financing sustainable growth',
#  'Decision No 1386/2013/EU',
#  'Regulation on the classification of environmentally sustainable economic activities',
#  'Regulation on requirements for environmentally sustainable financial products',
#  'Platform on Sustainable Finance',
#  'Taxonomy Regulation',
#  'Taxonomy Climate Delegated Act',
#  'Commission Delegated Regulation (EU) 2021/2139',
#  'EU Taxonomy Climate Delegated Act',
#  'Directive (EU) 2018/2001',
#  'Council Directive 2011/70/Euratom',
#  'Invest EU',
#  'Delegated Regulation 2021/2139',
#  'Union renewable energy financing mechanism',
#  'European Green Deal',
#  'Trans-European Networks - Energy (TEN-E) Regulation',
#  '25% target for climate mainstreaming across all EU programmes',
#  'Innovation and Modernisation Funds',
#  'Sustainable Europe Investment Plan, taxonomy for classifying environmentally sustainable activities',
#  'Non-Financial Reporting Directive',
#  'EU green bond standard',
#  'Horizon Europe',
#  'Neighbourhood',
#  'Development and International Cooperation Instrument',
#  'Clean Energy for EU Islands Initiative',
#  'Sustainable Finance Disclosures Regulation',
#  'Regulation (EU) 2020/852',
#  'EU Climate Transition Benchmark',
#  'EU Paris-aligned Benchmark',
#  'Next Generation EU',
#  'Recovery and Resilience Facility',
#  'Emissions Trading System-based own resource, carbon border adjustment mechanism',
#  'Programme for Environment and Climate Action (LIFE)',
#  'National Energy and Climate Plans',
#  'Energy efficiency renovation of existing housing stock, demonstration projects and supporting measures',
#  'Construction of new energy efficient buildings',
#  'Energy efficiency renovation or energy efficiency measures regarding public infrastructure, demonstration projects and supporting measures',
#  'Support to enterprises that provide services contributing to the low carbon economy and to resilience to climate change including awareness-raising measures',
#  'Renewable energy: wind',
#  'Renewable energy: marine',
#  'Other renewable energy (including geothermal energy)',
#  'European Rail Traffic Management System (ERTMS)',
#  'Digitalisation of transport when dedicated in part to GHG emissions reduction: road',
#  'Government ICT solutions, e-services, applications compliant with GHG emission reduction or energy efficiency criteria',
#  'Digitising SMEs compliant with GHG emission reduction or energy efficiency criteria',
#  'Regulation on sustainability risks integration',
#  'Regulation on sustainability-related disclosures in the financial services sector',
#  'Article 6 Disclosures',
#  'CBAM Transitional Registry',
#  'CBAM Trader Portal',
#  'European Regional Development Fund',
#  'Cohesion Fund, innovation fund',
#  'Guidelines on State aid for climate, environmental protection and energy 2022',
#  'Regulation (EU) 2021/1056 establishing the Just Transition Fund',
#  'JERICHO',
#  'Directive 2014/65/EU',
#  'Regulation (EU) 2022/869',
#  'New EU Forest Strategy for 2030',
#  'EU Soil Strategy for 2030',
#  'Social Climate Fund',
#  'European Local ENergy Assistance (ELENA)',
#  'Technical Support Instrument',
#  'Circular Economy Action Plan',
#  'Regulation on Land Use',
#  'Land Use Change, and Forestry (LULUCF)',
#  'CCS Directive',
#  'Proposed Regulation for Carbon Removals',
#  'Proposal for a Regulation of the European Parliament and of the Council establishing an European framework for carbon removal certification',
#  'EU 2018/1999 Governance Regulation',
#  'EU quality criteria for carbon removals, certification schemes for carbon removal activities',
#  'ETS Innovation Fund',
#  'IPCEI instrument',
#  'EU sustainable finance taxonomy',
#  'Renewable Energy Directive',
#  'carbon contracts for difference',
#  'InnovFin Energy Demonstration Projects',
#  'Interregional Innovation Investment Instrument',
#  'Western Balkans Investment Framework',
#  'European Fund for Sustainable Development',
#  'EU ETS',
#  'carbon border adjustment mechanism (CBAM)',
#  'CBAM certificates',
#  'CBAM Regulation',
#  'Global Gateway',
#  'EFSD+',
#  'EBA final draft ITS on Pillar 3 disclosures on ESG risks',
#  'Regulation (EU) No 575/2013 (Capital Requirements Regulation – CRR)',
#  'Pillar 3 framework on prudential disclosures on ESG risks',
#  'Climate Benchmark Regulation',
#  'Green Asset Ratio',
#  'Banking Book Taxonomy Alignment Ratio',
#  'Article 449a of Regulation (EU) No 575/2013',
#  'Corporate Sustainability Reporting Directive',
#  'CRR10',
#  'Regulation (EU) 2019/2033 (Investment Firms Regulation – IFR)',
#  'Article 449a CRR',
#  'Pillar 3 ESG ITS',
#  'NFRD',
#  'P3 ESG ITS',
#  'FINAL REPORT DRAFT ITS ON PRUDENTIAL DISCLOSURES ON ESG RISKS',
#  'FSB-TCFD recommendations',
#  'EBA Advice',
#  'COM DA',
#  'BTAR',
#  'Template 1 on ‘Banking book – climate change transition risk: credit quality of exposures by sector, emissions and residual maturity’',
#  'Template 2 on ‘Banking book – climate change transition risk: loans collateralised by immovable property – energy efficiency of the collateral’',
#  'Implementing Regulation (EU) 2021/637',
#  'Pillar 3 disclosure requirements',
#  'CSRD',
#  'Commission Delegated Regulation under Article 8 of the Taxonomy Regulation',
#  'Taxonomy on climate objectives',
#  'Article 435 CRR',
#  'Article 35 IFD',
#  'Equator Principles',
#  'EBA P3 ESG risk disclosures',
#  'TCFD report',
#  'EU Taxonomy Regulation',
#  'EBA report on management and supervision of ESG risks for credit institutions and investment firms',
#  'Partnership for Carbon Accounting Financials (PCAF)',
#  'Global GHG Accounting and Reporting Standard',
#  'CRR3 proposal',
#  'TCFD guidelines',
#  'Commission Guidelines on non-financial reporting: supplement on reporting climate-related information',
#  'EBA Prudential Disclosures on ESG Risks',
#  'GAR 1',
#  'Green Loan Principles',
#  'Sustainability-Linked Bond Principles',
#  'Energy efficiency renovation of existing housing stock, demonstration projects and supporting measures',
#  'European Code of Conduct on Data Centre Energy Efficiency',
#  'contract for difference, carbon contract for difference',
#  'Decision (EU) 2015/1814',
#  'Article 10a(8)',
#  'Commission Decision 2010/670/EU',
#  'Directive concerning the determination of sectors and subsectors deemed at risk of carbon leakage',
#  'CORSIA',
#  'Social Climate Fund established by Regulation (EU) 2023/955',
#  'Social Climate Plan',
#  'Innovation Fund, public sector loan facility under the Just Transition Mechanism',
#  'Connecting Europe Facility',
#  'Horizon 2020: Part III: Societal challenge 5: Climate action',
#  'Environment, resource efficiency and raw materials',
#  'LIFE: Climate Action and Environment',
#  'Regulation (EU) No 1293/2013 on the establishment of a Programme for the Environment and Climate Action (LIFE)',
#  'GAR for climate change mitigation',
#  'GAR for lending activities to equity holdings of non-financial undertakings for loans and advances (GAR L&A)',
#  'GAR for debt securities to non-financial undertakings',
#  'Green Direct Payment',
#  'Council Decision (EU) 2020/954',
#  'CEF',
#  'Loan Guarantee instrument for TEN-T projects',
#  'Risk-Sharing Finance Facility, 2020 European Fund for Energy',
#  'Europe 2020 Project Bond Initiative',
#  'Euratom) No 966/2012',
#  'Decision No 1639/2006/EC',
#  'Debt Instrument',
#  'EU Emissions Trading System Innovation Fund',
#  'European Green Deal Investment Plan',
#  'IPCEIs',
#  'JTF',
#  'European Social Fund Plus (ESF+)',
#  'Investment for jobs and growth goal',
#  'RCO 121',
#  'RCR 29',
#  'JTF Regulation',
#  'ERDF and CF Regulation',
#  'EMFAF',
#  'Partnership Agreement',
#  'InvestEU Regulation',
#  'climate proofing of investments in infrastructure',
#  'Recovery and Resilience Plan (Regulation (EU) 2021/241)',
#  'Article 11 CPR',
#  'Article 15',
#  'Article 6(2)',
#  'Directive (EU) 2010/31/EU of the European Parliament and of the Council',
#  'EUR 1 per tonne of CO2 equivalent allocation',
#  'EU taxonomy for sustainable activities',
#  'Renewed Sustainable Finance Strategy',
#  'National Recovery and Resilience Plans',
#  'Cohesion Policy programmes',
#  'European Investment Bank climate roadmap',
#  'EU Adaptation Strategy',
#  'EIOPA’s natural catastrophe dashboard',
#  'African Adaptation Initiative',
#  'African Risk Capacity',
#  'Green Climate Fund',
#  'Adaptation Fund',
#  'Directive (EU) 2018/410',
#  'Commission Regulation (EU) No 1031/2010',
#  'Green Deal Industrial Plan',
#  'Critical Raw Materials Act',
#  'Net-Zero Industry Act',
#  'Sovereignty Seal',
#  'Strategic Technologies for Europe Platform (STEP)',
#  'Council Directive 2003/96/EC']
